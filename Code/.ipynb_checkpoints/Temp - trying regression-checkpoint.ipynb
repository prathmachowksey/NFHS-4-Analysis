# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./../Data/working_data/normalised_data_6.csv')

# %%
df.drop(df.columns[[0]], axis = 1, inplace = True)

# %%
df
# Out:
#           District  Households surveyed  Women age 15-49 years interviewed  \
# 0           Chamba               578.31                             683.98
# 1           Chamba               626.02                             738.25
# 2           Kangra              1946.63                            2077.83
# 3           Kangra              2062.74                            2149.72
# 4     Lahul &Spiti                35.11                              29.59
# ...            ...                  ...                                ...
# 1287        Valsad               624.17                             679.94
# 1288         Surat              1733.85                            2019.23
# 1289         Surat              2195.68                            2511.26
# 1290          Tapi               262.75                             307.76
# 1291          Tapi               290.78                             338.97
#
#       Men age 15-49 years interviewed  \
# ...

# %%
df = df.drop(columns= ['District' , 'Households surveyed' , 'Women age 15-49 years interviewed' , 'Men age 15-49 years interviewed' , 'State', 'Region', 'Zone']  )

# %%
import statsmodels.api as sm

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
X = df.copy(deep='True')

# %%
X = X.drop(columns = ['68. Children under 5 years who are stunted11 (%)'])

# %%
Xcpy = X.copy(deep= 'True')

# %%
y = df['68. Children under 5 years who are stunted11 (%)']

# %%
y=y.values

# %%
X=X.values

# %%
y
# Out:
# array([0.2937, 0.299 , 0.2585, ..., 0.2997, 0.3635, 0.3587])

# %%
X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.637
# Model:                            OLS   Adj. R-squared:                  0.630
# Method:                 Least Squares   F-statistic:                     88.93
# Date:                Mon, 13 Apr 2020   Prob (F-statistic):          1.50e-257
# Time:                        11:38:41   Log-Likelihood:                 1796.6
# No. Observations:                1292   AIC:                            -3541.
# Df Residuals:                    1266   BIC:                            -3407.
# Df Model:                          25
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.5066      0.046     11.073      0.000       0.417       0.596
# ...

# %%
# variables with p-value < 0.05:

# '1. Population (female) age 6+ years who ever attended school (%)'
# '3. Sex ratio of the total population (females per 1000 males)'
#  '8. Households using improved sanitation facility2 (%)'
#  '12. Women who are literate (%)' , men - not significant
#  '15. Women age 20-24 years married before age 18 years (%)'
# '19. Any modern method (%)'
#  '30. Mothers who had at least 4 antenatal care visits (%)'
# 40. Institutional births (%)'
# '67. Total children age 6-23 months receiving an adequate diet9 10 (%)',
# '72. Women whose Body Mass Index (BMI) is below normal (BMI <18.5 kg/m2) (%)'
 #'76. Children age 6-59 months who are anaemic (<11.0 g/dl) (%)',
 #      '79. All women age 15-49 years who are anaemic (%)',


### meaningless : '92. Breast (%)', '93. Oral cavity (%)'
Xcpy.columns
#x1 , x2, x4, x6, x9(?) x10, x11, x13 ,x19, x20 , x21, x22, x24 , x25
# Out:
# Index(['1. Population (female) age 6+ years who ever attended school (%)',
#        '3. Sex ratio of the total population (females per 1000 males)',
#        '4. Sex ratio at birth for children born in the last five years (females per 1000 males)',
#        '8. Households using improved sanitation facility2 (%)',
#        '9. Households using clean fuel for cooking3 (%)',
#        '12. Women who are literate (%)', '13. Men who are literate (%)',
#        '14. Women with 10 or more years of schooling (%)',
#        '15. Women age 20-24 years married before age 18 years (%)',
#        '19. Any modern method (%)',
#        '30. Mothers who had at least 4 antenatal care visits (%)',
#        '32. Mothers who consumed iron folic acid for 100 days or more when they were pregnant (%)',
#        '40. Institutional births (%)',
#        '42. Home delivery conducted by skilled health personnel (out of total deliveries) (%)',
# ...

# %%
# Xcpy.drop(columns = [ '3. Sex ratio of the total population (females per 1000 males)',
#        '4. Sex ratio at birth for children born in the last five years (females per 1000 males)','19. Any modern method (%)', '42. Home delivery conducted by skilled health personnel (out of total deliveries) (%)', '91. Cervix (%)',
#        '92. Breast (%)', '93. Oral cavity (%)' , '79. All women age 15-49 years who are anaemic (%)'])

# %%
df_new = df[['1. Population (female) age 6+ years who ever attended school (%)' , '8. Households using improved sanitation facility2 (%)',
       '9. Households using clean fuel for cooking3 (%)',  '12. Women who are literate (%)', '13. Men who are literate (%)','32. Mothers who consumed iron folic acid for 100 days or more when they were pregnant (%)',
       '62. Children under age 3 years breastfed within one hour of birth8 (%)',
       '65. Breastfeeding children age 6-23 months receiving an adequate diet9 10 (%)',
       '67. Total children age 6-23 months receiving an adequate diet9 10 (%)','72. Women whose Body Mass Index (BMI) is below normal (BMI <18.5 kg/m2) (%)',
       '76. Children age 6-59 months who are anaemic (<11.0 g/dl) (%)',
       '79. All women age 15-49 years who are anaemic (%)']]

# %%
df_new
# Out:
#       1. Population (female) age 6+ years who ever attended school (%)  \
# 0                                                0.6751
# 1                                                0.6884
# 2                                                0.8337
# 3                                                0.8339
# 4                                                0.6569
# ...                                                 ...
# 1287                                             0.7647
# 1288                                             0.8570
# 1289                                             0.8285
# 1290                                             0.6256
# 1291                                             0.6475
#
#       8. Households using improved sanitation facility2 (%)  \
# 0                                                0.7505
# 1                                                0.7570
# 2                                                0.6675
# ...

# %%
y = df['68. Children under 5 years who are stunted11 (%)'].values
X = df['3. Sex ratio of the total population (females per 1000 males)'].values

# %%
X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     2.586
# Date:                Mon, 13 Apr 2020   Prob (F-statistic):              0.108
# Time:                        11:54:57   Log-Likelihood:                 1143.0
# No. Observations:                1292   AIC:                            -2282.
# Df Residuals:                    1290   BIC:                            -2272.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.3051      0.039      7.833      0.000       0.229       0.381
# ...
