# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv('./../Data/working_data/cleaned_data_3.csv')

# %%
data=data.drop(axis=1,index=0)
data
# Out:
#           District  \
# 1       Tamenglong
# 2    Churachandpur
# 3        Bishnupur
# 4        Bishnupur
# 5          Thoubal
# ..             ...
# 649       Longleng
# 650        Kiphire
# 651         Kohima
# 652         Kohima
# 653          Peren
#
#      1. Population (female) age 6+ years who ever attended school (%)  \
# 1                                                 69.5
# 2                                                 79.4
# 3                                                 82.3
# 4                                                 77.4
# 5                                                 80.8
# ..                                                 ...
# 649                                               77.9
# 650                                               72.2
# 651                                               91.9
# 652                                               78.2
# 653                                               75.6
#
# ...

# %%
data.columns
# Out:
# Index(['District',
#        '1. Population (female) age 6+ years who ever attended school (%)',
#        '4. Sex ratio at birth for children born in the last five years (females per 1000 males)',
#        '7. Households with an improved drinking-water source1 (%)',
#        '8. Households using improved sanitation facility2 (%)',
#        '9. Households using clean fuel for cooking3 (%)',
#        '10. Households using iodized salt (%)',
#        '12. Women who are literate (%)', '13. Men who are literate (%)',
#        '14. Women with 10 or more years of schooling (%)',
#        '15. Women age 20-24 years married before age 18 years (%)',
#        '19. Any modern method (%)', '25. Total unmet need (%)',
#        '30. Mothers who had at least 4 antenatal care visits (%)',
#        '32. Mothers who consumed iron folic acid for 100 days or more when they were pregnant (%)',
#        '40. Institutional births (%)',
# ...

# %%
data.shape
# Out:
# (653, 32)

# %%
sns.barplot(x=data['Region'].value_counts().index,
              y=data['Region'].value_counts().values)
plt.xlabel('Region')
plt.ylabel('Number of Districts')
plt.savefig('./../Plots/PRE ANALYSIS PLOTS/plot1.png')
plt.show()

# %%
sns.barplot(x=data['Zone'].value_counts().index,
              y=data['Zone'].value_counts().values)
plt.xlabel('Zone')
plt.ylabel('Number of Districts')
plt.xticks(rotation=90)

plt.savefig('./../Plots/PRE ANALYSIS PLOTS/plot2.png', bbox_inches='tight')

plt.show()

# %%
plt.figure(figsize=(10,4))
sns.barplot(x=data['State'].value_counts().index,
              y=data['State'].value_counts().values)
plt.xlabel('State')
plt.ylabel('Number of Districts')
# plt.xticks(weight='bold')
# plt.yticks(weight='bold')
plt.savefig('./../Plots/PRE ANALYSIS PLOTS/plot3.png')

plt.show()

# %%
sns.boxplot(x=data['Zone'],y=data['68. Children under 5 years who are stunted11 (%)'],hue=data['Region'],dodge=False)
plt.legend(loc=0)
#plt.title('Child Stunting in Rural and Urban Regions Across Various Zones',weight='bold')
plt.ylabel('Children Under 5 Years Who Are Stunted (%)')
plt.xticks(rotation=90)
plt.xlabel('Zone')
# plt.yticks(weight='bold')
plt.savefig('./../Plots/PRE ANALYSIS PLOTS/plot4.png')
plt.show()

# %%
#ax=plt.gca()
ax.set(xlim=(0,100),ylim=(0,100))
sns.lmplot(x='72. Women whose Body Mass Index (BMI) is below normal (BMI <18.5 kg/m2) (%)',y='68. Children under 5 years who are stunted11 (%)',hue='Region',data=data)
plt.xlabel('Women Whose Body Mass Index (BMI) Is Below Normal (%)')
plt.ylabel('Children Under 5 Years Who Are Stunted (%)')
# plt.title('Women with Below Normal BMI vs Child Stunting')
plt.savefig('./../Plots/PRE ANALYSIS PLOTS/pl