# %% [markdown]
# # <font size=14> Women and Child Health: Analysis of NFHS-4 Data </font>
# National Family Health Survey, 4 (2015-2016) - India
#
# - Data for this project has been taken from https://data.gov.in/
# - Link to the dataset: https://data.gov.in/catalog/key-indicators-national-family-health-survey-nfhs
# <br> </br>

# %% [markdown]
# # <font size=11> Data Preprocessing </font>
# The data is split across 30 files - one for each state of India. Each file contains district wise data for 93 attributes.

# %% [markdown]
# ## Merging the data from the 30 files into one single file, so as to facilitate analysis on an all India level

# %% [markdown]
# ## DATA PREPROCESSING: Feature Construction (State)

# %%
import os
import io
import pandas as pd
flag=0
for root, dirs, files in os.walk("./../Data/original_data"):
    for filename in files:
          name="./../Data/original_data" + "/"  +filename
          df=pd.read_csv(name)
          #print(df)
          df=df.transpose()
          df.columns = df.iloc[0]
          df=df.drop(df.index[0])
          statename=[]
          df=df.dropna(how='all')
          n=df.shape[0]

          name = filename.strip('.csv')
          for i in range(n):
            statename.append(name)

          df['State']=statename
          if(flag==0):
            dataset=df
            flag=1
          else:
            dataset=dataset.append(df)

# %%
print(dataset.shape)
# Out:
# (1549, 97)

# %%
dataset.to_csv('./../Data/working_data/merged_data_1.csv')

# %%
dataset=pd.read_csv('./../Data/working_data/merged_data_1.csv')

# %%
dataset=dataset.rename(columns={dataset.columns[0] : 'District' })

# %%
dataset
# Out:
#                    District  Households surveyed  \
# 0          Senapati - Rural                855.0
# 1          Senapati - Total                896.0
# 2        Tamenglong - Rural                777.0
# 3        Tamenglong - Total                905.0
# 4     Churachandpur - Rural                732.0
# ...                     ...                  ...
# 1544         Kohima - Urban                  NaN
# 1545         Kohima - Rural                  NaN
# 1546         Kohima - Total               1797.0
# 1547          Peren - Rural                  NaN
# 1548          Peren - Total                876.0
#
#       Women age 15-49 years interviewed  Men age 15-49 years interviewed  \
# 0                                1009.0                            134.0
# 1                                1052.0                            143.0
# 2                                 797.0                            111.0
# 3                                 964.0                            129.0
# 4                                 784.0                            105.0
# ...                                 ...                              ...
# 1544                                NaN                              NaN
# 1545                                NaN                              NaN
# 1546                             1787.0                            215.0
# 1547                                NaN                              NaN
# 1548                              809.0                            119.0
#
#       1. Population (female) age 6+ years who ever attended school (%)  \
# 0                                                  79.7
# 1                                                  80.1
# 2                                                  69.5
# 3                                                  72.7
# 4                                                  79.4
# ...                                                 ...
# 1544                                               91.9
# 1545                                               78.2
# 1546                                               86.2
# 1547                                               75.6
# 1548                                               78.9
#
#       2. Population below age 15 years (%)  \
# 0                                     33.5
# 1                                     33.6
# 2                                     36.1
# 3                                     35.9
# 4                                     35.1
# ...                                    ...
# 1544                                  26.8
# 1545                                  31.6
# 1546                                  28.8
# 1547                                  37.1
# 1548                                  38.3
#
#       3. Sex ratio of the total population (females per 1000 males)  \
# 0                                                 989.0
# 1                                                 986.0
# 2                                                1021.0
# 3                                                1031.0
# 4                                                 992.0
# ...                                                 ...
# 1544                                              997.0
# 1545                                             1003.0
# 1546                                             1000.0
# 1547                                              960.0
# 1548                                              992.0
#
#       4. Sex ratio at birth for children born in the last five years (females per 1000 males)  \
# 0                                                 856.0
# 1                                                 858.0
# 2                                                1158.0
# 3                                                1150.0
# 4                                                 998.0
# ...                                                 ...
# 1544                                             1139.0
# 1545                                             1135.0
# 1546                                             1137.0
# 1547                                              937.0
# 1548                                              916.0
#
#       5. Children under age 5 years whose birth was registered (%)  \
# 0                                                  48.6
# 1                                                  49.9
# 2                                                  56.9
# 3                                                  59.3
# 4                                                  66.8
# ...                                                 ...
# 1544                                               80.8
# 1545                                               77.4
# 1546                                               79.1
# 1547                                               63.0
# 1548                                               69.3
#
#       6. Households with electricity (%)  ...  \
# 0                                   92.4  ...
# 1                                   92.7  ...
# 2                                   85.6  ...
# 3                                   87.9  ...
# 4                                   88.1  ...
# ...                                  ...  ...
# 1544                                99.7  ...
# 1545                                99.1  ...
# 1546                                99.4  ...
# 1547                                97.2  ...
# 1548                                97.3  ...
#
#       85. Slightly above normal (Systolic 140-159 mm of Hg and/or Diastolic 90-99 mm of Hg) (%)  \
# 0                                                   6.7
# 1                                                   6.6
# 2                                                   8.4
# 3                                                   7.8
# 4                                                   7.0
# ...                                                 ...
# 1544                                               11.3
# 1545                                               12.8
# 1546                                               11.9
# 1547                                               11.0
# 1548                                               11.3
#
#       86. Moderately high (Systolic 160-179 mm of Hg and/or Diastolic 100-109 mm of Hg) (%)  \
# 0                                                   1.4
# 1                                                   1.6
# 2                                                   1.6
# 3                                                   1.8
# 4                                                   0.1
# ...                                                 ...
# 1544                                                4.3
# 1545                                                4.5
# 1546                                                4.4
# 1547                                                2.6
# 1548                                                2.4
#
#       87. Very high (Systolic ?180 mm of Hg and/or Diastolic ?110 mm of Hg) (%)  \
# 0                                                   1.2
# 1                                                   1.1
# 2                                                   1.3
# 3                                                   1.3
# 4                                                   0.7
# ...                                                 ...
# 1544                                                2.2
# 1545                                                3.0
# 1546                                                2.5
# 1547                                                1.3
# 1548                                                1.3
#
#       88. Slightly above normal (Systolic 140-159 mm of Hg and/or Diastolic 90-99 mm of Hg) (%)  \
# 0                                                  17.0
# 1                                                  17.7
# 2                                                  11.1
# 3                                                  11.0
# 4                                                  14.1
# ...                                                 ...
# 1544                                               20.8
# 1545                                               17.6
# 1546                                               19.9
# 1547                                               17.7
# 1548                                               23.2
#
#       89. Moderately high (Systolic 160-179 mm of Hg and/or Diastolic 100-109 mm of Hg) (%)  \
# 0                                                   3.4
# 1                                                   3.2
# 2                                                   2.1
# 3                                                   1.6
# 4                                                   0.0
# ...                                                 ...
# 1544                                                7.9
# 1545                                                9.6
# 1546                                                8.3
# 1547                                                2.5
# 1548                                                4.2
#
#       90. Very high (Systolic ?180 mm of Hg and/or Diastolic ?110 mm of Hg) (%)  \
# 0                                                   0.6
# 1                                                   0.6
# 2                                                   1.1
# 3                                                   3.2
# 4                                                   5.3
# ...                                                 ...
# 1544                                                2.2
# 1545                                                0.0
# 1546                                                1.6
# 1547                                                1.1
# 1548                                                0.8
#
#       91. Cervix (%)  92. Breast (%)  93. Oral cavity (%)  State
# 0               13.6             2.7                 10.4     MN
# 1               13.6             2.8                 10.7     MN
# 2               13.6             1.7                  7.9     MN
# 3               13.5             1.9                  8.1     MN
# 4               10.7             1.3                  8.1     MN
# ...              ...             ...                  ...    ...
# 1544            23.0             3.0                 28.3     NL
# 1545            21.5             1.6                 15.7     NL
# 1546            22.4             2.5                 23.6     NL
# 1547            23.6             2.0                  8.8     NL
# 1548            23.7             2.1                 10.0     NL
#
# [1549 rows x 98 columns]

# %% [markdown]
# ## DATA PREPROCESSING: Feature Contruction: Region

# %%
region=[]
district=[]

n=dataset.shape[0]
for i in range(n):
    
    name=dataset.iloc[i]['District']
    
    if(name.find('Rural')!=-1):
        
        name=name.replace('- Rural', '')
        name=name.replace('-Rural', '')
        
        name=name.strip()
        district.append(name)
        region.append('Rural')
        
    elif(name.find('Urban')!=-1):
        name=name.replace('- Urban', '')
        name=name.replace('-Urban', '')
        name=name.strip()
        district.append(name)
        region.append('Urban')
        
    elif(name.find('Total')!=-1):
        name=name.replace('- Total', '')
        name=name.replace('-Total', '')
        name=name.strip()
        district.append(name)
        region.append('Total')
       
print(len(region))
print(len(district))
print(dataset.shape[0])
# Out:
# 1549
# 1549
# 1549

# %%
dataset['Region']=region
dataset['District']=district
dataset
# Out:
#            District  Households surveyed  Women age 15-49 years interviewed  \
# 0          Senapati                855.0                             1009.0
# 1          Senapati                896.0                             1052.0
# 2        Tamenglong                777.0                              797.0
# 3        Tamenglong                905.0                              964.0
# 4     Churachandpur                732.0                              784.0
# ...             ...                  ...                                ...
# 1544         Kohima                  NaN                                NaN
# 1545         Kohima                  NaN                                NaN
# 1546         Kohima               1797.0                             1787.0
# 1547          Peren                  NaN                                NaN
# 1548          Peren                876.0                              809.0
#
#       Men age 15-49 years interviewed  \
# 0                               134.0
# 1                               143.0
# 2                               111.0
# 3                               129.0
# 4                               105.0
# ...                               ...
# 1544                              NaN
# 1545                              NaN
# 1546                            215.0
# 1547                              NaN
# 1548                            119.0
#
#       1. Population (female) age 6+ years who ever attended school (%)  \
# 0                                                  79.7
# 1                                                  80.1
# 2                                                  69.5
# 3                                                  72.7
# 4                                                  79.4
# ...                                                 ...
# 1544                                               91.9
# 1545                                               78.2
# 1546                                               86.2
# 1547                                               75.6
# 1548                                               78.9
#
#       2. Population below age 15 years (%)  \
# 0                                     33.5
# 1                                     33.6
# 2                                     36.1
# 3                                     35.9
# 4                                     35.1
# ...                                    ...
# 1544                                  26.8
# 1545                                  31.6
# 1546                                  28.8
# 1547                                  37.1
# 1548                                  38.3
#
#       3. Sex ratio of the total population (females per 1000 males)  \
# 0                                                 989.0
# 1                                                 986.0
# 2                                                1021.0
# 3                                                1031.0
# 4                                                 992.0
# ...                                                 ...
# 1544                                              997.0
# 1545                                             1003.0
# 1546                                             1000.0
# 1547                                              960.0
# 1548                                              992.0
#
#       4. Sex ratio at birth for children born in the last five years (females per 1000 males)  \
# 0                                                 856.0
# 1                                                 858.0
# 2                                                1158.0
# 3                                                1150.0
# 4                                                 998.0
# ...                                                 ...
# 1544                                             1139.0
# 1545                                             1135.0
# 1546                                             1137.0
# 1547                                              937.0
# 1548                                              916.0
#
#       5. Children under age 5 years whose birth was registered (%)  \
# 0                                                  48.6
# 1                                                  49.9
# 2                                                  56.9
# 3                                                  59.3
# 4                                                  66.8
# ...                                                 ...
# 1544                                               80.8
# 1545                                               77.4
# 1546                                               79.1
# 1547                                               63.0
# 1548                                               69.3
#
#       6. Households with electricity (%)  ...  \
# 0                                   92.4  ...
# 1                                   92.7  ...
# 2                                   85.6  ...
# 3                                   87.9  ...
# 4                                   88.1  ...
# ...                                  ...  ...
# 1544                                99.7  ...
# 1545                                99.1  ...
# 1546                                99.4  ...
# 1547                                97.2  ...
# 1548                                97.3  ...
#
#       86. Moderately high (Systolic 160-179 mm of Hg and/or Diastolic 100-109 mm of Hg) (%)  \
# 0                                                   1.4
# 1                                                   1.6
# 2                                                   1.6
# 3                                                   1.8
# 4                                                   0.1
# ...                                                 ...
# 1544                                                4.3
# 1545                                                4.5
# 1546                                                4.4
# 1547                                                2.6
# 1548                                                2.4
#
#       87. Very high (Systolic ?180 mm of Hg and/or Diastolic ?110 mm of Hg) (%)  \
# 0                                                   1.2
# 1                                                   1.1
# 2                                                   1.3
# 3                                                   1.3
# 4                                                   0.7
# ...                                                 ...
# 1544                                                2.2
# 1545                                                3.0
# 1546                                                2.5
# 1547                                                1.3
# 1548                                                1.3
#
#       88. Slightly above normal (Systolic 140-159 mm of Hg and/or Diastolic 90-99 mm of Hg) (%)  \
# 0                                                  17.0
# 1                                                  17.7
# 2                                                  11.1
# 3                                                  11.0
# 4                                                  14.1
# ...                                                 ...
# 1544                                               20.8
# 1545                                               17.6
# 1546                                               19.9
# 1547                                               17.7
# 1548                                               23.2
#
#       89. Moderately high (Systolic 160-179 mm of Hg and/or Diastolic 100-109 mm of Hg) (%)  \
# 0                                                   3.4
# 1                                                   3.2
# 2                                                   2.1
# 3                                                   1.6
# 4                                                   0.0
# ...                                                 ...
# 1544                                                7.9
# 1545                                                9.6
# 1546                                                8.3
# 1547                                                2.5
# 1548                                                4.2
#
#       90. Very high (Systolic ?180 mm of Hg and/or Diastolic ?110 mm of Hg) (%)  \
# 0                                                   0.6
# 1                                                   0.6
# 2                                                   1.1
# 3                                                   3.2
# 4                                                   5.3
# ...                                                 ...
# 1544                                                2.2
# 1545                                                0.0
# 1546                                                1.6
# 1547                                                1.1
# 1548                                                0.8
#
#       91. Cervix (%)  92. Breast (%)  93. Oral cavity (%)  State  Region
# 0               13.6             2.7                 10.4     MN   Rural
# 1               13.6             2.8                 10.7     MN   Total
# 2               13.6             1.7                  7.9     MN   Rural
# 3               13.5             1.9                  8.1     MN   Total
# 4               10.7             1.3                  8.1     MN   Rural
# ...              ...             ...                  ...    ...     ...
# 1544            23.0             3.0                 28.3     NL   Urban
# 1545            21.5             1.6                 15.7     NL   Rural
# 1546            22.4             2.5                 23.6     NL   Total
# 1547            23.6             2.0                  8.8     NL   Rural
# 1548            23.7             2.1                 10.0     NL   Total
#
# [1549 rows x 99 columns]

# %% [markdown]
# ## DATA PREPROCESSING: Feature Construction : Zone

# %%
zone={ 'Southern Zone' : ['AP', 'TN' , 'KL', 'KA', 'TG'] , 'Western Zone' : ['GA', 'MH', 'GJ'] , 'Eastern Zone' : ['OR','WB', 'BR', 'JH', 'SK'] , 'North Eastern Zone' : ['AR','NL','MN','MZ','ML','AS','TR'], 'Central Zone' : ['MP' , 'CT' , 'UP' , 'UT'], 'Northern Zone' : ['RJ', 'DL' , 'PB' , 'HR' , 'HP' , 'JK']}

# %%
zone_list=[]
n=dataset.shape[0]
for i in range(n):
    name=dataset.iloc[i]['State']
    for z in zone:
        if name in zone[z]:
            zone_list.append(z)
print(len(zone_list))
print(n)
# Out:
# 1549
# 1549

# %%
dataset['Zone']=zone_list
dataset
# Out:
#            District  Households surveyed  Women age 15-49 years interviewed  \
# 0          Senapati                855.0                             1009.0
# 1          Senapati                896.0                             1052.0
# 2        Tamenglong                777.0                              797.0
# 3        Tamenglong                905.0                              964.0
# 4     Churachandpur                732.0                              784.0
# ...             ...                  ...                                ...
# 1544         Kohima                  NaN                                NaN
# 1545         Kohima                  NaN                                NaN
# 1546         Kohima               1797.0                             1787.0
# 1547          Peren                  NaN                                NaN
# 1548          Peren                876.0                              809.0
#
#       Men age 15-49 years interviewed  \
# 0                               134.0
# 1                               143.0
# 2                               111.0
# 3                               129.0
# 4                               105.0
# ...                               ...
# 1544                              NaN
# 1545                              NaN
# 1546                            215.0
# 1547                              NaN
# 1548                            119.0
#
#       1. Population (female) age 6+ years who ever attended school (%)  \
# 0                                                  79.7
# 1                                                  80.1
# 2                                                  69.5
# 3                                                  72.7
# 4                                                  79.4
# ...                                                 ...
# 1544                                               91.9
# 1545                                               78.2
# 1546                                               86.2
# 1547                                               75.6
# 1548                                               78.9
#
#       2. Population below age 15 years (%)  \
# 0                                     33.5
# 1                                     33.6
# 2                                     36.1
# 3                                     35.9
# 4                                     35.1
# ...                                    ...
# 1544                                  26.8
# 1545                                  31.6
# 1546                                  28.8
# 1547                                  37.1
# 1548                                  38.3
#
#       3. Sex ratio of the total population (females per 1000 males)  \
# 0                                                 989.0
# 1                                                 986.0
# 2                                                1021.0
# 3                                                1031.0
# 4                                                 992.0
# ...                                                 ...
# 1544                                              997.0
# 1545                                             1003.0
# 1546                                             1000.0
# 1547                                              960.0
# 1548                                              992.0
#
#       4. Sex ratio at birth for children born in the last five years (females per 1000 males)  \
# 0                                                 856.0
# 1                                                 858.0
# 2                                                1158.0
# 3                                                1150.0
# 4                                                 998.0
# ...                                                 ...
# 1544                                             1139.0
# 1545                                             1135.0
# 1546                                             1137.0
# 1547                                              937.0
# 1548                                              916.0
#
#       5. Children under age 5 years whose birth was registered (%)  \
# 0                                                  48.6
# 1                                                  49.9
# 2                                                  56.9
# 3                                                  59.3
# 4                                                  66.8
# ...                                                 ...
# 1544                                               80.8
# 1545                                               77.4
# 1546                                               79.1
# 1547                                               63.0
# 1548                                               69.3
#
#       6. Households with electricity (%)  ...  \
# 0                                   92.4  ...
# 1                                   92.7  ...
# 2                                   85.6  ...
# 3                                   87.9  ...
# 4                                   88.1  ...
# ...                                  ...  ...
# 1544                                99.7  ...
# 1545                                99.1  ...
# 1546                                99.4  ...
# 1547                                97.2  ...
# 1548                                97.3  ...
#
#       87. Very high (Systolic ?180 mm of Hg and/or Diastolic ?110 mm of Hg) (%)  \
# 0                                                   1.2
# 1                                                   1.1
# 2                                                   1.3
# 3                                                   1.3
# 4                                                   0.7
# ...                                                 ...
# 1544                                                2.2
# 1545                                                3.0
# 1546                                                2.5
# 1547                                                1.3
# 1548                                                1.3
#
#       88. Slightly above normal (Systolic 140-159 mm of Hg and/or Diastolic 90-99 mm of Hg) (%)  \
# 0                                                  17.0
# 1                                                  17.7
# 2                                                  11.1
# 3                                                  11.0
# 4                                                  14.1
# ...                                                 ...
# 1544                                               20.8
# 1545                                               17.6
# 1546                                               19.9
# 1547                                               17.7
# 1548                                               23.2
#
#       89. Moderately high (Systolic 160-179 mm of Hg and/or Diastolic 100-109 mm of Hg) (%)  \
# 0                                                   3.4
# 1                                                   3.2
# 2                                                   2.1
# 3                                                   1.6
# 4                                                   0.0
# ...                                                 ...
# 1544                                                7.9
# 1545                                                9.6
# 1546                                                8.3
# 1547                                                2.5
# 1548                                                4.2
#
#       90. Very high (Systolic ?180 mm of Hg and/or Diastolic ?110 mm of Hg) (%)  \
# 0                                                   0.6
# 1                                                   0.6
# 2                                                   1.1
# 3                                                   3.2
# 4                                                   5.3
# ...                                                 ...
# 1544                                                2.2
# 1545                                                0.0
# 1546                                                1.6
# 1547                                                1.1
# 1548                                                0.8
#
#       91. Cervix (%)  92. Breast (%)  93. Oral cavity (%)  State  Region  \
# 0               13.6             2.7                 10.4     MN   Rural
# 1               13.6             2.8                 10.7     MN   Total
# 2               13.6             1.7                  7.9     MN   Rural
# 3               13.5             1.9                  8.1     MN   Total
# 4               10.7             1.3                  8.1     MN   Rural
# ...              ...             ...                  ...    ...     ...
# 1544            23.0             3.0                 28.3     NL   Urban
# 1545            21.5             1.6                 15.7     NL   Rural
# 1546            22.4             2.5                 23.6     NL   Total
# 1547            23.6             2.0                  8.8     NL   Rural
# 1548            23.7             2.1                 10.0     NL   Total
#
#                     Zone
# 0     North Eastern Zone
# 1     North Eastern Zone
# 2     North Eastern Zone
# 3     North Eastern Zone
# 4     North Eastern Zone
# ...                  ...
# 1544  North Eastern Zone
# 1545  North Eastern Zone
# 1546  North Eastern Zone
# 1547  North Eastern Zone
# 1548  North Eastern Zone
#
# [1549 rows x 100 columns]

# %%
dataset.to_csv('./../Data/working_data/feature_constructed_data_2.csv', index=False)

# %%
dataset=pd.read_csv('./../Data/working_data/feature_constructed_data_2.csv')
dataset
# Out:
#            District  Households surveyed  Women age 15-49 years interviewed  \
# 0          Senapati                855.0                             1009.0
# 1          Senapati                896.0                             1052.0
# 2        Tamenglong                777.0                              797.0
# 3        Tamenglong                905.0                              964.0
# 4     Churachandpur                732.0                              784.0
# ...             ...                  ...                                ...
# 1544         Kohima                  NaN                                NaN
# 1545         Kohima                  NaN                                NaN
# 1546         Kohima               1797.0                             1787.0
# 1547          Peren                  NaN                                NaN
# 1548          Peren                876.0                              809.0
#
#       Men age 15-49 years interviewed  \
# 0                               134.0
# 1                               143.0
# 2                               111.0
# 3                               129.0
# 4                               105.0
# ...                               ...
# 1544                              NaN
# 1545                              NaN
# 1546                            215.0
# 1547                              NaN
# 1548                            119.0
#
#       1. Population (female) age 6+ years who ever attended school (%)  \
# 0                                                  79.7
# 1                                                  80.1
# 2                                                  69.5
# 3                                                  72.7
# 4                                                  79.4
# ...                                                 ...
# 1544                                               91.9
# 1545                                               78.2
# 1546                                               86.2
# 1547                                               75.6
# 1548                                               78.9
#
#       2. Population below age 15 years (%)  \
# 0                                     33.5
# 1                                     33.6
# 2                                     36.1
# 3                                     35.9
# 4                                     35.1
# ...                                    ...
# 1544                                  26.8
# 1545                                  31.6
# 1546                                  28.8
# 1547                                  37.1
# 1548                                  38.3
#
#       3. Sex ratio of the total population (females per 1000 males)  \
# 0                                                 989.0
# 1                                                 986.0
# 2                                                1021.0
# 3                                                1031.0
# 4                                                 992.0
# ...                                                 ...
# 1544                                              997.0
# 1545                                             1003.0
# 1546                                             1000.0
# 1547                                              960.0
# 1548                                              992.0
#
#       4. Sex ratio at birth for children born in the last five years (females per 1000 males)  \
# 0                                                 856.0
# 1                                                 858.0
# 2                                                1158.0
# 3                                                1150.0
# 4                                                 998.0
# ...                                                 ...
# 1544                                             1139.0
# 1545                                             1135.0
# 1546                                             1137.0
# 1547                                              937.0
# 1548                                              916.0
#
#       5. Children under age 5 years whose birth was registered (%)  \
# 0                                                  48.6
# 1                                                  49.9
# 2                                                  56.9
# 3                                                  59.3
# 4                                                  66.8
# ...                                                 ...
# 1544                                               80.8
# 1545                                               77.4
# 1546                                               79.1
# 1547                                               63.0
# 1548                                               69.3
#
#       6. Households with electricity (%)  ...  \
# 0                                   92.4  ...
# 1                                   92.7  ...
# 2                                   85.6  ...
# 3                                   87.9  ...
# 4                                   88.1  ...
# ...                                  ...  ...
# 1544                                99.7  ...
# 1545                                99.1  ...
# 1546                                99.4  ...
# 1547                                97.2  ...
# 1548                                97.3  ...
#
#       87. Very high (Systolic ?180 mm of Hg and/or Diastolic ?110 mm of Hg) (%)  \
# 0                                                   1.2
# 1                                                   1.1
# 2                                                   1.3
# 3                                                   1.3
# 4                                                   0.7
# ...                                                 ...
# 1544                                                2.2
# 1545                                                3.0
# 1546                                                2.5
# 1547                                                1.3
# 1548                                                1.3
#
#       88. Slightly above normal (Systolic 140-159 mm of Hg and/or Diastolic 90-99 mm of Hg) (%)  \
# 0                                                  17.0
# 1                                                  17.7
# 2                                                  11.1
# 3                                                  11.0
# 4                                                  14.1
# ...                                                 ...
# 1544                                               20.8
# 1545                                               17.6
# 1546                                               19.9
# 1547                                               17.7
# 1548                                               23.2
#
#       89. Moderately high (Systolic 160-179 mm of Hg and/or Diastolic 100-109 mm of Hg) (%)  \
# 0                                                   3.4
# 1                                                   3.2
# 2                                                   2.1
# 3                                                   1.6
# 4                                                   0.0
# ...                                                 ...
# 1544                                                7.9
# 1545                                                9.6
# 1546                                                8.3
# 1547                                                2.5
# 1548                                                4.2
#
#       90. Very high (Systolic ?180 mm of Hg and/or Diastolic ?110 mm of Hg) (%)  \
# 0                                                   0.6
# 1                                                   0.6
# 2                                                   1.1
# 3                                                   3.2
# 4                                                   5.3
# ...                                                 ...
# 1544                                                2.2
# 1545                                                0.0
# 1546                                                1.6
# 1547                                                1.1
# 1548                                                0.8
#
#       91. Cervix (%)  92. Breast (%)  93. Oral cavity (%)  State  Region  \
# 0               13.6             2.7                 10.4     MN   Rural
# 1               13.6             2.8                 10.7     MN   Total
# 2               13.6             1.7                  7.9     MN   Rural
# 3               13.5             1.9                  8.1     MN   Total
# 4               10.7             1.3                  8.1     MN   Rural
# ...              ...             ...                  ...    ...     ...
# 1544            23.0             3.0                 28.3     NL   Urban
# 1545            21.5             1.6                 15.7     NL   Rural
# 1546            22.4             2.5                 23.6     NL   Total
# 1547            23.6             2.0                  8.8     NL   Rural
# 1548            23.7             2.1                 10.0     NL   Total
#
#                     Zone
# 0     North Eastern Zone
# 1     North Eastern Zone
# 2     North Eastern Zone
# 3     North Eastern Zone
# 4     North Eastern Zone
# ...                  ...
# 1544  North Eastern Zone
# 1545  North Eastern Zone
# 1546  North Eastern Zone
# 1547  North Eastern Zone
# 1548  North Eastern Zone
#
# [1549 rows x 100 columns]

# %%
dataset.isna().sum().sum()
# Out:
# 14889

# %% [markdown]
# ## Data Cleaning : Removing rows with 'Households Surveyed' == 0

# %%
dataset=dataset[dataset['Households surveyed'] != 0.00]

    
dataset
# Out:
#            District  Households surveyed  Women age 15-49 years interviewed  \
# 0          Senapati                855.0                             1009.0
# 1          Senapati                896.0                             1052.0
# 2        Tamenglong                777.0                              797.0
# 3        Tamenglong                905.0                              964.0
# 4     Churachandpur                732.0                              784.0
# ...             ...                  ...                                ...
# 1544         Kohima                  NaN                                NaN
# 1545         Kohima                  NaN                                NaN
# 1546         Kohima               1797.0                             1787.0
# 1547          Peren                  NaN                                NaN
# 1548          Peren                876.0                              809.0
#
#       Men age 15-49 years interviewed  \
# 0                               134.0
# 1                               143.0
# 2                               111.0
# 3                               129.0
# 4                               105.0
# ...                               ...
# 1544                              NaN
# 1545                              NaN
# 1546                            215.0
# 1547                              NaN
# 1548                            119.0
#
#       1. Population (female) age 6+ years who ever attended school (%)  \
# 0                                                  79.7
# 1                                                  80.1
# 2                                                  69.5
# 3                                                  72.7
# 4                                                  79.4
# ...                                                 ...
# 1544                                               91.9
# 1545                                               78.2
# 1546                                               86.2
# 1547                                               75.6
# 1548                                               78.9
#
#       2. Population below age 15 years (%)  \
# 0                                     33.5
# 1                                     33.6
# 2                                     36.1
# 3                                     35.9
# 4                                     35.1
# ...                                    ...
# 1544                                  26.8
# 1545                                  31.6
# 1546                                  28.8
# 1547                                  37.1
# 1548                                  38.3
#
#       3. Sex ratio of the total population (females per 1000 males)  \
# 0                                                 989.0
# 1                                                 986.0
# 2                                                1021.0
# 3                                                1031.0
# 4                                                 992.0
# ...                                                 ...
# 1544                                              997.0
# 1545                                             1003.0
# 1546                                             1000.0
# 1547                                              960.0
# 1548                                              992.0
#
#       4. Sex ratio at birth for children born in the last five years (females per 1000 males)  \
# 0                                                 856.0
# 1                                                 858.0
# 2                                                1158.0
# 3                                                1150.0
# 4                                                 998.0
# ...                                                 ...
# 1544                                             1139.0
# 1545                                             1135.0
# 1546                                             1137.0
# 1547                                              937.0
# 1548                                              916.0
#
#       5. Children under age 5 years whose birth was registered (%)  \
# 0                                                  48.6
# 1                                                  49.9
# 2                                                  56.9
# 3                                                  59.3
# 4                                                  66.8
# ...                                                 ...
# 1544                                               80.8
# 1545                                               77.4
# 1546                                               79.1
# 1547                                               63.0
# 1548                                               69.3
#
#       6. Households with electricity (%)  ...  \
# 0                                   92.4  ...
# 1                                   92.7  ...
# 2                                   85.6  ...
# 3                                   87.9  ...
# 4                                   88.1  ...
# ...                                  ...  ...
# 1544                                99.7  ...
# 1545                                99.1  ...
# 1546                                99.4  ...
# 1547                                97.2  ...
# 1548                                97.3  ...
#
#       87. Very high (Systolic ?180 mm of Hg and/or Diastolic ?110 mm of Hg) (%)  \
# 0                                                   1.2
# 1                                                   1.1
# 2                                                   1.3
# 3                                                   1.3
# 4                                                   0.7
# ...                                                 ...
# 1544                                                2.2
# 1545                                                3.0
# 1546                                                2.5
# 1547                                                1.3
# 1548                                                1.3
#
#       88. Slightly above normal (Systolic 140-159 mm of Hg and/or Diastolic 90-99 mm of Hg) (%)  \
# 0                                                  17.0
# 1                                                  17.7
# 2                                                  11.1
# 3                                                  11.0
# 4                                                  14.1
# ...                                                 ...
# 1544                                               20.8
# 1545                                               17.6
# 1546                                               19.9
# 1547                                               17.7
# 1548                                               23.2
#
#       89. Moderately high (Systolic 160-179 mm of Hg and/or Diastolic 100-109 mm of Hg) (%)  \
# 0                                                   3.4
# 1                                                   3.2
# 2                                                   2.1
# 3                                                   1.6
# 4                                                   0.0
# ...                                                 ...
# 1544                                                7.9
# 1545                                                9.6
# 1546                                                8.3
# 1547                                                2.5
# 1548                                                4.2
#
#       90. Very high (Systolic ?180 mm of Hg and/or Diastolic ?110 mm of Hg) (%)  \
# 0                                                   0.6
# 1                                                   0.6
# 2                                                   1.1
# 3                                                   3.2
# 4                                                   5.3
# ...                                                 ...
# 1544                                                2.2
# 1545                                                0.0
# 1546                                                1.6
# 1547                                                1.1
# 1548                                                0.8
#
#       91. Cervix (%)  92. Breast (%)  93. Oral cavity (%)  State  Region  \
# 0               13.6             2.7                 10.4     MN   Rural
# 1               13.6             2.8                 10.7     MN   Total
# 2               13.6             1.7                  7.9     MN   Rural
# 3               13.5             1.9                  8.1     MN   Total
# 4               10.7             1.3                  8.1     MN   Rural
# ...              ...             ...                  ...    ...     ...
# 1544            23.0             3.0                 28.3     NL   Urban
# 1545            21.5             1.6                 15.7     NL   Rural
# 1546            22.4             2.5                 23.6     NL   Total
# 1547            23.6             2.0                  8.8     NL   Rural
# 1548            23.7             2.1                 10.0     NL   Total
#
#                     Zone
# 0     North Eastern Zone
# 1     North Eastern Zone
# 2     North Eastern Zone
# 3     North Eastern Zone
# 4     North Eastern Zone
# ...                  ...
# 1544  North Eastern Zone
# 1545  North Eastern Zone
# 1546  North Eastern Zone
# 1547  North Eastern Zone
# 1548  North Eastern Zone
#
# [1540 rows x 100 columns]

# %%
dataset.isna().sum()
# Out:
# District                                                             0
# Households surveyed                                                 14
# Women age 15-49 years interviewed                                   13
# Men age 15-49 years interviewed                                     13
# 1. Population (female) age 6+ years who ever attended school (%)     0
#                                                                     ..
# 92. Breast (%)                                                       1
# 93. Oral cavity (%)                                                  1
# State                                                                0
# Region                                                               0
# Zone                                                                 0
# Length: 100, dtype: int64

# %%
dataset.isna().sum().sum()
# Out:
# 14052

# %% [markdown]
# ## Dividing attributes into categories

# %%
attribute_categories={'population' : [] , 'literacy' : [] , 'marriage': [] , 'family_planning' : [] , 'maternity_care' : [] , 'delivery_care': [], 'child_immunisation' : [] , 'childhood_diseases' : [] , 'child_nutrition':[], 'adult_nutrition':[], 'anaemia': [], 'blood_sugar_level' : [], 'hypertension': [] , 'women_examination' : []    }

# %%
for i in range(len(dataset.columns)):
                if(i<=14):
                   attribute_categories['population'].append(dataset.columns[i])
                elif(i<=17):
                    attribute_categories['literacy'].append(dataset.columns[i])
                elif(i<=20):
                    attribute_categories['marriage'].append(dataset.columns[i])
                elif(i<=31):
                    attribute_categories['family_planning'].append(dataset.columns[i])
                elif(i<=42):
                    attribute_categories['maternity_care'].append(dataset.columns[i])
                elif(i<=49):
                    attribute_categories['delivery_care'].append(dataset.columns[i])
                elif(i<=58):
                    attribute_categories['child_immunisation'].append(dataset.columns[i])
                elif(i<=64):
                    attribute_categories['childhood_diseases'].append(dataset.columns[i])
                elif(i<=74):
                    attribute_categories['child_nutrition'].append(dataset.columns[i])
                elif(i<=78):
                    attribute_categories['adult_nutrition'].append(dataset.columns[i])
                elif(i<=83):
                    attribute_categories['anaemia'].append(dataset.columns[i])
                elif(i<=87):
                    attribute_categories['blood_sugar_level'].append(dataset.columns[i])
                elif(i<=90):
                    attribute_categories['hypertension'].append(dataset.columns[i])
                elif(i<=93):
                    attribute_categories['hypertension'].append(dataset.columns[i])
                elif(i<=96):
                    attribute_categories['women_examination'].append(dataset.columns[i])
                else:
                    attribute_categories['population'].append(dataset.columns[i])

# %%
attribute_categories
# Out:
# {'population': ['District',
#   'Households surveyed',
#   'Women age 15-49 years interviewed',
#   'Men age 15-49 years interviewed',
#   '1. Population (female) age 6+ years who ever attended school (%)',
#   '2. Population below age 15 years (%)',
#   '3. Sex ratio of the total population (females per 1000 males)',
#   '4. Sex ratio at birth for children born in the last five years (females per 1000 males)',
#   '5. Children under age 5 years whose birth was registered (%)',
#   '6. Households with electricity (%)',
#   '7. Households with an improved drinking-water source1 (%)',
#   '8. Households using improved sanitation facility2 (%)',
#   '9. Households using clean fuel for cooking3 (%)',
#   '10. Households using iodized salt (%)',
#   '11. Households with any usual member covered by a health scheme or health insurance (%)',
#   'State',
#   'Region',
#   'Zone'],
#  'literacy': ['12. Women who are literate (%)',
#   '13. Men who are literate (%)',
#   '14. Women with 10 or more years of schooling (%)'],
#  'marriage': ['15. Women age 20-24 years married before age 18 years (%)',
#   '16. Men age 25-29 years married before age 21 years (%)',
#   '17. Women age 15-19 years who were already mothers or pregnant at the time of the survey (%)'],
#  'family_planning': ['18. Any method (%)',
#   '19. Any modern method (%)',
#   '20. Female sterilization (%)',
#   '21. Male sterilization (%)',
#   '22. IUD/PPIUD (%)',
#   '23. Pill (%)',
#   '24. Condom (%)',
#   '25. Total unmet need (%)',
#   '26. Unmet need for spacing (%)',
#   '27. Health worker ever talked to female non-users about family planning5 (%)',
#   '28. Current users ever told about side effects of current method (%)'],
#  'maternity_care': ['29. Mothers who had antenatal check-up in the first trimester (%)',
#   '30. Mothers who had at least 4 antenatal care visits (%)',
#   '31. Mothers whose last birth was protected against neonatal tetanus6 (%)',
#   '32. Mothers who consumed iron folic acid for 100 days or more when they were pregnant (%)',
#   '33. Mothers who had full antenatal care7 (%)',
#   '34. Registered pregnancies for which the mother received Mother and Child Protection (MCP) card (%)',
#   '35. Mothers who received postnatal care from a doctor/nurse/LHV/ANM/midwife/other health personnel within 2 days of delivery (%)',
#   '36. Mothers who received financial assistance under Janani Suraksha Yojana (JSY) for births delivered in an institution (%)',
#   '37. Average out of pocket expenditure per delivery in public health facility (Rs.)',
#   '38. Children born at home who were taken to a health facility for check-up within 24 hours of birth (%)',
#   '39. Children who received postnatal care from a doctor/nurse/LHV/ANM/midwife/other health personnel within 2 days of delivery (%)'],
#  'delivery_care': ['40. Institutional births (%)',
#   '41. Institutional births in public facility (%)',
#   '42. Home delivery conducted by skilled health personnel (out of total deliveries) (%)',
#   '43. Births assisted by a doctor/nurse/LHV/ANM/other health personnel (%)',
#   '44. Births delivered by caesarean section (%)',
#   '45. Births in a private health facility delivered by caesarean section (%)',
#   '46. Births in a public health facility delivered by caesarean section (%)'],
#  'child_immunisation': ['47. Children age 12-23 months fully immunized (BCG measles and 3 doses each of polio/DPT) (%)',
#   '48. Children age 12-23 months who have received BCG (%)',
#   '49. Children age 12-23 months who have received 3 doses of polio vaccine (%)',
#   '50. Children age 12-23 months who have received 3 doses of DPT vaccine (%)',
#   '51. Children age 12-23 months who have received measles vaccine (%)',
#   '52. Children age 12-23 months who have received 3 doses of Hepatitis B vaccine (%)',
#   '53. Children age 9-59 months who received a vitamin A dose in last 6 months (%)',
#   '54. Children age 12-23 months who received most of the vaccinations in public health facility (%)',
#   '55. Children age 12-23 months who received most of the vaccinations in private health facility (%)'],
#  'childhood_diseases': ['56. Prevalence of diarrhoea (reported) in the last 2 weeks preceding the survey (%)',
#   '57. Children with diarrhoea in the last 2 weeks who received oral rehydration salts (ORS) (%)',
#   '58. Children with diarrhoea in the last 2 weeks who received zinc (%)',
#   '59. Children with diarrhoea in the last 2 weeks taken to a health facility (%)',
#   '60. Prevalence of symptoms of acute respiratory infection (ARI) in the last 2 weeks preceding the survey (%)',
#   '61. Children with fever or symptoms of ARI in the last 2 weeks preceding the survey taken to a health facility (%)'],
#  'child_nutrition': ['62. Children under age 3 years breastfed within one hour of birth8 (%)',
#   '63. Children under age 6 months exclusively breastfed9 (%)',
#   '64. Children age 6-8 months receiving solid or semi-solid food and breastmilk9 (%)',
#   '65. Breastfeeding children age 6-23 months receiving an adequate diet9 10 (%)',
#   '66. Non-breastfeeding children age 6-23 months receiving an adequate diet9 10 (%)',
#   '67. Total children age 6-23 months receiving an adequate diet9 10 (%)',
#   '68. Children under 5 years who are stunted11 (%)',
#   '69. Children under 5 years who are wasted11 (%)',
#   '70. Children under 5 years who are severely wasted12 (%)',
#   '71. Children under 5 years who are underweight11 (%)'],
#  'adult_nutrition': ['72. Women whose Body Mass Index (BMI) is below normal (BMI <18.5 kg/m2) (%)',
#   '73. Men whose Body Mass Index (BMI) is below normal (BMI <18.5 kg/m2) (%)',
#   '74. Women who are overweight or obese (BMI >=25.0 kg/m2) (%)',
#   '75. Men who are overweight or obese (BMI >=25.0 kg/m2) (%)'],
#  'anaemia': ['76. Children age 6-59 months who are anaemic (<11.0 g/dl) (%)',
#   '77. Non-pregnant women age 15-49 years who are anaemic (<12.0 g/dl) (%)',
#   '78. Pregnant women age 15-49 years who are anaemic (<11.0 g/dl) (%)',
#   '79. All women age 15-49 years who are anaemic (%)',
#   '80. Men age 15-49 years who are anaemic (<13.0 g/dl) (%)'],
#  'blood_sugar_level': ['81. Blood sugar level - high (>140 mg/dl) (%)',
#   '82. Blood sugar level - very high (>160 mg/dl) (%)',
#   '83. Blood sugar level - high (>140 mg/dl) (%)',
#   '84. Blood sugar level - very high (>160 mg/dl) (%)'],
#  'hypertension': ['85. Slightly above normal (Systolic 140-159 mm of Hg and/or Diastolic 90-99 mm of Hg) (%)',
#   '86. Moderately high (Systolic 160-179 mm of Hg and/or Diastolic 100-109 mm of Hg) (%)',
#   '87. Very high (Systolic ?180 mm of Hg and/or Diastolic ?110 mm of Hg) (%)',
#   '88. Slightly above normal (Systolic 140-159 mm of Hg and/or Diastolic 90-99 mm of Hg) (%)',
#   '89. Moderately high (Systolic 160-179 mm of Hg and/or Diastolic 100-109 mm of Hg) (%)',
#   '90. Very high (Systolic ?180 mm of Hg and/or Diastolic ?110 mm of Hg) (%)'],
#  'women_examination': ['91. Cervix (%)',
#   '92. Breast (%)',
#   '93. Oral cavity (%)']}

# %%
dataset_2=dataset[dataset['Region'] != 'Total']

    
print(dataset_2.isna().sum())
print(dataset_2.shape)
# Out:
# District                                                             0
# Households surveyed                                                 14
# Women age 15-49 years interviewed                                   13
# Men age 15-49 years interviewed                                     13
# 1. Population (female) age 6+ years who ever attended school (%)     0
#                                                                     ..
# 92. Breast (%)                                                       1
# 93. Oral cavity (%)                                                  1
# State                                                                0
# Region                                                               0
# Zone                                                                 0
# Length: 100, dtype: int64
# (913, 100)

# %%
dataset_2.isna().sum().sum()
# Out:
# 11028

# %% [markdown]
# ## Data Cleaning : Removing attributes with many missing (NA) values

# %%
pd.set_option('display.max_rows', 500)
num_of_na=list(dataset_2.isna().sum())
columns_to_drop=[]
for i in range(len(num_of_na)):
    if num_of_na[i] >= 0.3*dataset_2.shape[0]:
        
        
        columns_to_drop.append(dataset_2.columns[i])

print(columns_to_drop)
dataset2=dataset_2.drop(columns_to_drop,axis=1)
print(dataset2.shape[1])
print(dataset_2.shape[1])
# Out:
# ['16. Men age 25-29 years married before age 21 years (%)', '38. Children born at home who were taken to a health facility for check-up within 24 hours of birth (%)', '45. Births in a private health facility delivered by caesarean section (%)', '57. Children with diarrhoea in the last 2 weeks who received oral rehydration salts (ORS) (%)', '58. Children with diarrhoea in the last 2 weeks who received zinc (%)', '59. Children with diarrhoea in the last 2 weeks taken to a health facility (%)', '61. Children with fever or symptoms of ARI in the last 2 weeks preceding the survey taken to a health facility (%)', '63. Children under age 6 months exclusively breastfed9 (%)', '64. Children age 6-8 months receiving solid or semi-solid food and breastmilk9 (%)', '66. Non-breastfeeding children age 6-23 months receiving an adequate diet9 10 (%)', '78. Pregnant women age 15-49 years who are anaemic (<11.0 g/dl) (%)']
# 89
# 100

# %%
dataset2.isna().sum().sum()
# Out:
# 4576

# %%
dataset2.columns
# Out:
# Index(['District', 'Households surveyed', 'Women age 15-49 years interviewed',
#        'Men age 15-49 years interviewed',
#        '1. Population (female) age 6+ years who ever attended school (%)',
#        '2. Population below age 15 years (%)',
#        '3. Sex ratio of the total population (females per 1000 males)',
#        '4. Sex ratio at birth for children born in the last five years (females per 1000 males)',
#        '5. Children under age 5 years whose birth was registered (%)',
#        '6. Households with electricity (%)',
#        '7. Households with an improved drinking-water source1 (%)',
#        '8. Households using improved sanitation facility2 (%)',
#        '9. Households using clean fuel for cooking3 (%)',
#        '10. Households using iodized salt (%)',
#        '11. Households with any usual member covered by a health scheme or health insurance (%)',
#        '12. Women who are literate (%)', '13. Men who are literate (%)',
#        '14. Women with 10 or more years of schooling (%)',
#        '15. Women age 20-24 years married before age 18 years (%)',
#        '17. Women age 15-19 years who were already mothers or pregnant at the time of the survey (%)',
#        '18. Any method (%)', '19. Any modern method (%)',
#        '20. Female sterilization (%)', '21. Male sterilization (%)',
#        '22. IUD/PPIUD (%)', '23. Pill (%)', '24. Condom (%)',
#        '25. Total unmet need (%)', '26. Unmet need for spacing (%)',
#        '27. Health worker ever talked to female non-users about family planning5 (%)',
#        '28. Current users ever told about side effects of current method (%)',
#        '29. Mothers who had antenatal check-up in the first trimester (%)',
#        '30. Mothers who had at least 4 antenatal care visits (%)',
#        '31. Mothers whose last birth was protected against neonatal tetanus6 (%)',
#        '32. Mothers who consumed iron folic acid for 100 days or more when they were pregnant (%)',
#        '33. Mothers who had full antenatal care7 (%)',
#        '34. Registered pregnancies for which the mother received Mother and Child Protection (MCP) card (%)',
#        '35. Mothers who received postnatal care from a doctor/nurse/LHV/ANM/midwife/other health personnel within 2 days of delivery (%)',
#        '36. Mothers who received financial assistance under Janani Suraksha Yojana (JSY) for births delivered in an institution (%)',
#        '37. Average out of pocket expenditure per delivery in public health facility (Rs.)',
#        '39. Children who received postnatal care from a doctor/nurse/LHV/ANM/midwife/other health personnel within 2 days of delivery (%)',
#        '40. Institutional births (%)',
#        '41. Institutional births in public facility (%)',
#        '42. Home delivery conducted by skilled health personnel (out of total deliveries) (%)',
#        '43. Births assisted by a doctor/nurse/LHV/ANM/other health personnel (%)',
#        '44. Births delivered by caesarean section (%)',
#        '46. Births in a public health facility delivered by caesarean section (%)',
#        '47. Children age 12-23 months fully immunized (BCG measles and 3 doses each of polio/DPT) (%)',
#        '48. Children age 12-23 months who have received BCG (%)',
#        '49. Children age 12-23 months who have received 3 doses of polio vaccine (%)',
#        '50. Children age 12-23 months who have received 3 doses of DPT vaccine (%)',
#        '51. Children age 12-23 months who have received measles vaccine (%)',
#        '52. Children age 12-23 months who have received 3 doses of Hepatitis B vaccine (%)',
#        '53. Children age 9-59 months who received a vitamin A dose in last 6 months (%)',
#        '54. Children age 12-23 months who received most of the vaccinations in public health facility (%)',
#        '55. Children age 12-23 months who received most of the vaccinations in private health facility (%)',
#        '56. Prevalence of diarrhoea (reported) in the last 2 weeks preceding the survey (%)',
#        '60. Prevalence of symptoms of acute respiratory infection (ARI) in the last 2 weeks preceding the survey (%)',
#        '62. Children under age 3 years breastfed within one hour of birth8 (%)',
#        '65. Breastfeeding children age 6-23 months receiving an adequate diet9 10 (%)',
#        '67. Total children age 6-23 months receiving an adequate diet9 10 (%)',
#        '68. Children under 5 years who are stunted11 (%)',
#        '69. Children under 5 years who are wasted11 (%)',
#        '70. Children under 5 years who are severely wasted12 (%)',
#        '71. Children under 5 years who are underweight11 (%)',
#        '72. Women whose Body Mass Index (BMI) is below normal (BMI <18.5 kg/m2) (%)',
#        '73. Men whose Body Mass Index (BMI) is below normal (BMI <18.5 kg/m2) (%)',
#        '74. Women who are overweight or obese (BMI >=25.0 kg/m2) (%)',
#        '75. Men who are overweight or obese (BMI >=25.0 kg/m2) (%)',
#        '76. Children age 6-59 months who are anaemic (<11.0 g/dl) (%)',
#        '77. Non-pregnant women age 15-49 years who are anaemic (<12.0 g/dl) (%)',
#        '79. All women age 15-49 years who are anaemic (%)',
#        '80. Men age 15-49 years who are anaemic (<13.0 g/dl) (%)',
#        '81. Blood sugar level - high (>140 mg/dl) (%)',
#        '82. Blood sugar level - very high (>160 mg/dl) (%)',
#        '83. Blood sugar level - high (>140 mg/dl) (%)',
#        '84. Blood sugar level - very high (>160 mg/dl) (%)',
#        '85. Slightly above normal (Systolic 140-159 mm of Hg and/or Diastolic 90-99 mm of Hg) (%)',
#        '86. Moderately high (Systolic 160-179 mm of Hg and/or Diastolic 100-109 mm of Hg) (%)',
#        '87. Very high (Systolic ?180 mm of Hg and/or Diastolic ?110 mm of Hg) (%)',
#        '88. Slightly above normal (Systolic 140-159 mm of Hg and/or Diastolic 90-99 mm of Hg) (%)',
#        '89. Moderately high (Systolic 160-179 mm of Hg and/or Diastolic 100-109 mm of Hg) (%)',
#        '90. Very high (Systolic ?180 mm of Hg and/or Diastolic ?110 mm of Hg) (%)',
#        '91. Cervix (%)', '92. Breast (%)', '93. Oral cavity (%)', 'State',
#        'Region', 'Zone'],
#       dtype='object')

# %%
len(dataset2.columns)
# Out:
# 89

# %%
dataset2.corr()['68. Children under 5 years who are stunted11 (%)']
# Out:
# Households surveyed                                                                                                                  0.156765
# Women age 15-49 years interviewed                                                                                                    0.194477
# Men age 15-49 years interviewed                                                                                                      0.073544
# 1. Population (female) age 6+ years who ever attended school (%)                                                                    -0.577464
# 2. Population below age 15 years (%)                                                                                                 0.677540
# 3. Sex ratio of the total population (females per 1000 males)                                                                        0.008757
# 4. Sex ratio at birth for children born in the last five years (females per 1000 males)                                             -0.029723
# 5. Children under age 5 years whose birth was registered (%)                                                                        -0.485172
# 6. Households with electricity (%)                                                                                                  -0.586164
# 7. Households with an improved drinking-water source1 (%)                                                                            0.005558
# 8. Households using improved sanitation facility2 (%)                                                                               -0.607010
# 9. Households using clean fuel for cooking3 (%)                                                                                     -0.520680
# 10. Households using iodized salt (%)                                                                                               -0.112023
# 11. Households with any usual member covered by a health scheme or health insurance (%)                                             -0.291284
# 12. Women who are literate (%)                                                                                                      -0.650422
# 13. Men who are literate (%)                                                                                                        -0.514971
# 14. Women with 10 or more years of schooling (%)                                                                                    -0.591046
# 15. Women age 20-24 years married before age 18 years (%)                                                                            0.538721
# 17. Women age 15-19 years who were already mothers or pregnant at the time of the survey (%)                                         0.268249
# 18. Any method (%)                                                                                                                  -0.242526
# 19. Any modern method (%)                                                                                                           -0.269643
# 20. Female sterilization (%)                                                                                                        -0.110683
# 21. Male sterilization (%)                                                                                                          -0.101187
# 22. IUD/PPIUD (%)                                                                                                                   -0.272373
# 23. Pill (%)                                                                                                                        -0.124883
# 24. Condom (%)                                                                                                                      -0.127591
# 25. Total unmet need (%)                                                                                                             0.214041
# 26. Unmet need for spacing (%)                                                                                                       0.142893
# 27. Health worker ever talked to female non-users about family planning5 (%)                                                        -0.081365
# 28. Current users ever told about side effects of current method (%)                                                                -0.207077
# 29. Mothers who had antenatal check-up in the first trimester (%)                                                                   -0.488159
# 30. Mothers who had at least 4 antenatal care visits (%)                                                                            -0.572111
# 31. Mothers whose last birth was protected against neonatal tetanus6 (%)                                                            -0.029673
# 32. Mothers who consumed iron folic acid for 100 days or more when they were pregnant (%)                                           -0.490050
# 33. Mothers who had full antenatal care7 (%)                                                                                        -0.507273
# 34. Registered pregnancies for which the mother received Mother and Child Protection (MCP) card (%)                                 -0.139611
# 35. Mothers who received postnatal care from a doctor/nurse/LHV/ANM/midwife/other health personnel within 2 days of delivery (%)    -0.457386
# 36. Mothers who received financial assistance under Janani Suraksha Yojana (JSY) for births delivered in an institution (%)          0.366885
# 37. Average out of pocket expenditure per delivery in public health facility (Rs.)                                                  -0.266661
# 39. Children who received postnatal care from a doctor/nurse/LHV/ANM/midwife/other health personnel within 2 days of delivery (%)   -0.223621
# 40. Institutional births (%)                                                                                                        -0.455087
# 41. Institutional births in public facility (%)                                                                                     -0.097300
# 42. Home delivery conducted by skilled health personnel (out of total deliveries) (%)                                                0.264234
# 43. Births assisted by a doctor/nurse/LHV/ANM/other health personnel (%)                                                            -0.463439
# 44. Births delivered by caesarean section (%)                                                                                       -0.598222
# 46. Births in a public health facility delivered by caesarean section (%)                                                           -0.606337
# 47. Children age 12-23 months fully immunized (BCG measles and 3 doses each of polio/DPT) (%)                                       -0.290314
# 48. Children age 12-23 months who have received BCG (%)                                                                             -0.111012
# 49. Children age 12-23 months who have received 3 doses of polio vaccine (%)                                                        -0.269135
# 50. Children age 12-23 months who have received 3 doses of DPT vaccine (%)                                                          -0.250695
# 51. Children age 12-23 months who have received measles vaccine (%)                                                                 -0.204716
# 52. Children age 12-23 months who have received 3 doses of Hepatitis B vaccine (%)                                                  -0.284542
# 53. Children age 9-59 months who received a vitamin A dose in last 6 months (%)                                                     -0.299153
# 54. Children age 12-23 months who received most of the vaccinations in public health facility (%)                                    0.095430
# 55. Children age 12-23 months who received most of the vaccinations in private health facility (%)                                  -0.307889
# 56. Prevalence of diarrhoea (reported) in the last 2 weeks preceding the survey (%)                                                  0.198947
# 60. Prevalence of symptoms of acute respiratory infection (ARI) in the last 2 weeks preceding the survey (%)                         0.024156
# 62. Children under age 3 years breastfed within one hour of birth8 (%)                                                              -0.277880
# 65. Breastfeeding children age 6-23 months receiving an adequate diet9 10 (%)                                                       -0.369382
# 67. Total children age 6-23 months receiving an adequate diet9 10 (%)                                                               -0.412613
# 68. Children under 5 years who are stunted11 (%)                                                                                     1.000000
# 69. Children under 5 years who are wasted11 (%)                                                                                      0.247307
# 70. Children under 5 years who are severely wasted12 (%)                                                                             0.120229
# 71. Children under 5 years who are underweight11 (%)                                                                                 0.767173
# 72. Women whose Body Mass Index (BMI) is below normal (BMI <18.5 kg/m2) (%)                                                          0.633503
# 73. Men whose Body Mass Index (BMI) is below normal (BMI <18.5 kg/m2) (%)                                                            0.552667
# 74. Women who are overweight or obese (BMI >=25.0 kg/m2) (%)                                                                        -0.636356
# 75. Men who are overweight or obese (BMI >=25.0 kg/m2) (%)                                                                          -0.573015
# 76. Children age 6-59 months who are anaemic (<11.0 g/dl) (%)                                                                        0.383067
# 77. Non-pregnant women age 15-49 years who are anaemic (<12.0 g/dl) (%)                                                              0.276866
# 79. All women age 15-49 years who are anaemic (%)                                                                                    0.282893
# 80. Men age 15-49 years who are anaemic (<13.0 g/dl) (%)                                                                             0.328163
# 81. Blood sugar level - high (>140 mg/dl) (%)                                                                                       -0.382776
# 82. Blood sugar level - very high (>160 mg/dl) (%)                                                                                  -0.405969
# 83. Blood sugar level - high (>140 mg/dl) (%)                                                                                       -0.188734
# 84. Blood sugar level - very high (>160 mg/dl) (%)                                                                                  -0.221248
# 85. Slightly above normal (Systolic 140-159 mm of Hg and/or Diastolic 90-99 mm of Hg) (%)                                           -0.316447
# 86. Moderately high (Systolic 160-179 mm of Hg and/or Diastolic 100-109 mm of Hg) (%)                                               -0.286862
# 87. Very high (Systolic ?180 mm of Hg and/or Diastolic ?110 mm of Hg) (%)                                                           -0.150381
# 88. Slightly above normal (Systolic 140-159 mm of Hg and/or Diastolic 90-99 mm of Hg) (%)                                           -0.273260
# 89. Moderately high (Systolic 160-179 mm of Hg and/or Diastolic 100-109 mm of Hg) (%)                                               -0.231085
# 90. Very high (Systolic ?180 mm of Hg and/or Diastolic ?110 mm of Hg) (%)                                                           -0.167482
# 91. Cervix (%)                                                                                                                      -0.328280
# 92. Breast (%)                                                                                                                      -0.321384
# 93. Oral cavity (%)                                                                                                                 -0.489341
# Name: 68. Children under 5 years who are stunted11 (%), dtype: float64

# %% [markdown]
# ## DATA PREPROCESSING :  Feature Subset Selection <br/> ( Based on domain knowledge and correlation between different attributes)

# %% [markdown]
# ### Attribute Subset Selection (Irrelevant Features)

# %%
dataset3=dataset2.drop(['Households surveyed',
                        'Women age 15-49 years interviewed',
       'Men age 15-49 years interviewed',
       '2. Population below age 15 years (%)',
       '5. Children under age 5 years whose birth was registered (%)',
        '27. Health worker ever talked to female non-users about family planning5 (%)',
        '28. Current users ever told about side effects of current method (%)',
        '34. Registered pregnancies for which the mother received Mother and Child Protection (MCP) card (%)',
        '36. Mothers who received financial assistance under Janani Suraksha Yojana (JSY) for births delivered in an institution (%)',
                      '37. Average out of pocket expenditure per delivery in public health facility (Rs.)',
                        '56. Prevalence of diarrhoea (reported) in the last 2 weeks preceding the survey (%)',
                        '60. Prevalence of symptoms of acute respiratory infection (ARI) in the last 2 weeks preceding the survey (%)',
       '81. Blood sugar level - high (>140 mg/dl) (%)',
       '82. Blood sugar level - very high (>160 mg/dl) (%)',
       '83. Blood sugar level - high (>140 mg/dl) (%)',
       '84. Blood sugar level - very high (>160 mg/dl) (%)',
       '85. Slightly above normal (Systolic 140-159 mm of Hg and/or Diastolic 90-99 mm of Hg) (%)',
       '86. Moderately high (Systolic 160-179 mm of Hg and/or Diastolic 100-109 mm of Hg) (%)',
       '87. Very high (Systolic ?180 mm of Hg and/or Diastolic ?110 mm of Hg) (%)',
       '88. Slightly above normal (Systolic 140-159 mm of Hg and/or Diastolic 90-99 mm of Hg) (%)',
       '89. Moderately high (Systolic 160-179 mm of Hg and/or Diastolic 100-109 mm of Hg) (%)',
       '90. Very high (Systolic ?180 mm of Hg and/or Diastolic ?110 mm of Hg) (%)',
       '91. Cervix (%)', 
       '92. Breast (%)', 
       '93. Oral cavity (%)',
                       ], axis=1)

# %%
len(dataset3.columns)
# Out:
# 64

# %%
dataset3.isna().sum().sum()
# Out:
# 3635

# %% [markdown]
# ### Correlation Matrix

# %%
attribute_categories
# Out:
# {'population': ['District',
#   'Households surveyed',
#   'Women age 15-49 years interviewed',
#   'Men age 15-49 years interviewed',
#   '1. Population (female) age 6+ years who ever attended school (%)',
#   '2. Population below age 15 years (%)',
#   '3. Sex ratio of the total population (females per 1000 males)',
#   '4. Sex ratio at birth for children born in the last five years (females per 1000 males)',
#   '5. Children under age 5 years whose birth was registered (%)',
#   '6. Households with electricity (%)',
#   '7. Households with an improved drinking-water source1 (%)',
#   '8. Households using improved sanitation facility2 (%)',
#   '9. Households using clean fuel for cooking3 (%)',
#   '10. Households using iodized salt (%)',
#   '11. Households with any usual member covered by a health scheme or health insurance (%)',
#   'State',
#   'Region',
#   'Zone'],
#  'literacy': ['12. Women who are literate (%)',
#   '13. Men who are literate (%)',
#   '14. Women with 10 or more years of schooling (%)'],
#  'marriage': ['15. Women age 20-24 years married before age 18 years (%)',
#   '16. Men age 25-29 years married before age 21 years (%)',
#   '17. Women age 15-19 years who were already mothers or pregnant at the time of the survey (%)'],
#  'family_planning': ['18. Any method (%)',
#   '19. Any modern method (%)',
#   '20. Female sterilization (%)',
#   '21. Male sterilization (%)',
#   '22. IUD/PPIUD (%)',
#   '23. Pill (%)',
#   '24. Condom (%)',
#   '25. Total unmet need (%)',
#   '26. Unmet need for spacing (%)',
#   '27. Health worker ever talked to female non-users about family planning5 (%)',
#   '28. Current users ever told about side effects of current method (%)'],
#  'maternity_care': ['29. Mothers who had antenatal check-up in the first trimester (%)',
#   '30. Mothers who had at least 4 antenatal care visits (%)',
#   '31. Mothers whose last birth was protected against neonatal tetanus6 (%)',
#   '32. Mothers who consumed iron folic acid for 100 days or more when they were pregnant (%)',
#   '33. Mothers who had full antenatal care7 (%)',
#   '34. Registered pregnancies for which the mother received Mother and Child Protection (MCP) card (%)',
#   '35. Mothers who received postnatal care from a doctor/nurse/LHV/ANM/midwife/other health personnel within 2 days of delivery (%)',
#   '36. Mothers who received financial assistance under Janani Suraksha Yojana (JSY) for births delivered in an institution (%)',
#   '37. Average out of pocket expenditure per delivery in public health facility (Rs.)',
#   '38. Children born at home who were taken to a health facility for check-up within 24 hours of birth (%)',
#   '39. Children who received postnatal care from a doctor/nurse/LHV/ANM/midwife/other health personnel within 2 days of delivery (%)'],
#  'delivery_care': ['40. Institutional births (%)',
#   '41. Institutional births in public facility (%)',
#   '42. Home delivery conducted by skilled health personnel (out of total deliveries) (%)',
#   '43. Births assisted by a doctor/nurse/LHV/ANM/other health personnel (%)',
#   '44. Births delivered by caesarean section (%)',
#   '45. Births in a private health facility delivered by caesarean section (%)',
#   '46. Births in a public health facility delivered by caesarean section (%)'],
#  'child_immunisation': ['47. Children age 12-23 months fully immunized (BCG measles and 3 doses each of polio/DPT) (%)',
#   '48. Children age 12-23 months who have received BCG (%)',
#   '49. Children age 12-23 months who have received 3 doses of polio vaccine (%)',
#   '50. Children age 12-23 months who have received 3 doses of DPT vaccine (%)',
#   '51. Children age 12-23 months who have received measles vaccine (%)',
#   '52. Children age 12-23 months who have received 3 doses of Hepatitis B vaccine (%)',
#   '53. Children age 9-59 months who received a vitamin A dose in last 6 months (%)',
#   '54. Children age 12-23 months who received most of the vaccinations in public health facility (%)',
#   '55. Children age 12-23 months who received most of the vaccinations in private health facility (%)'],
#  'childhood_diseases': ['56. Prevalence of diarrhoea (reported) in the last 2 weeks preceding the survey (%)',
#   '57. Children with diarrhoea in the last 2 weeks who received oral rehydration salts (ORS) (%)',
#   '58. Children with diarrhoea in the last 2 weeks who received zinc (%)',
#   '59. Children with diarrhoea in the last 2 weeks taken to a health facility (%)',
#   '60. Prevalence of symptoms of acute respiratory infection (ARI) in the last 2 weeks preceding the survey (%)',
#   '61. Children with fever or symptoms of ARI in the last 2 weeks preceding the survey taken to a health facility (%)'],
#  'child_nutrition': ['62. Children under age 3 years breastfed within one hour of birth8 (%)',
#   '63. Children under age 6 months exclusively breastfed9 (%)',
#   '64. Children age 6-8 months receiving solid or semi-solid food and breastmilk9 (%)',
#   '65. Breastfeeding children age 6-23 months receiving an adequate diet9 10 (%)',
#   '66. Non-breastfeeding children age 6-23 months receiving an adequate diet9 10 (%)',
#   '67. Total children age 6-23 months receiving an adequate diet9 10 (%)',
#   '68. Children under 5 years who are stunted11 (%)',
#   '69. Children under 5 years who are wasted11 (%)',
#   '70. Children under 5 years who are severely wasted12 (%)',
#   '71. Children under 5 years who are underweight11 (%)'],
#  'adult_nutrition': ['72. Women whose Body Mass Index (BMI) is below normal (BMI <18.5 kg/m2) (%)',
#   '73. Men whose Body Mass Index (BMI) is below normal (BMI <18.5 kg/m2) (%)',
#   '74. Women who are overweight or obese (BMI >=25.0 kg/m2) (%)',
#   '75. Men who are overweight or obese (BMI >=25.0 kg/m2) (%)'],
#  'anaemia': ['76. Children age 6-59 months who are anaemic (<11.0 g/dl) (%)',
#   '77. Non-pregnant women age 15-49 years who are anaemic (<12.0 g/dl) (%)',
#   '78. Pregnant women age 15-49 years who are anaemic (<11.0 g/dl) (%)',
#   '79. All women age 15-49 years who are anaemic (%)',
#   '80. Men age 15-49 years who are anaemic (<13.0 g/dl) (%)'],
#  'blood_sugar_level': ['81. Blood sugar level - high (>140 mg/dl) (%)',
#   '82. Blood sugar level - very high (>160 mg/dl) (%)',
#   '83. Blood sugar level - high (>140 mg/dl) (%)',
#   '84. Blood sugar level - very high (>160 mg/dl) (%)'],
#  'hypertension': ['85. Slightly above normal (Systolic 140-159 mm of Hg and/or Diastolic 90-99 mm of Hg) (%)',
#   '86. Moderately high (Systolic 160-179 mm of Hg and/or Diastolic 100-109 mm of Hg) (%)',
#   '87. Very high (Systolic ?180 mm of Hg and/or Diastolic ?110 mm of Hg) (%)',
#   '88. Slightly above normal (Systolic 140-159 mm of Hg and/or Diastolic 90-99 mm of Hg) (%)',
#   '89. Moderately high (Systolic 160-179 mm of Hg and/or Diastolic 100-109 mm of Hg) (%)',
#   '90. Very high (Systolic ?180 mm of Hg and/or Diastolic ?110 mm of Hg) (%)'],
#  'women_examination': ['91. Cervix (%)',
#   '92. Breast (%)',
#   '93. Oral cavity (%)']}

# %%
dataset2.isna().sum()
# Out:
# District                                                                                                                               0
# Households surveyed                                                                                                                   14
# Women age 15-49 years interviewed                                                                                                     13
# Men age 15-49 years interviewed                                                                                                       13
# 1. Population (female) age 6+ years who ever attended school (%)                                                                       0
# 2. Population below age 15 years (%)                                                                                                   0
# 3. Sex ratio of the total population (females per 1000 males)                                                                          0
# 4. Sex ratio at birth for children born in the last five years (females per 1000 males)                                               77
# 5. Children under age 5 years whose birth was registered (%)                                                                          27
# 6. Households with electricity (%)                                                                                                     1
# 7. Households with an improved drinking-water source1 (%)                                                                              1
# 8. Households using improved sanitation facility2 (%)                                                                                  1
# 9. Households using clean fuel for cooking3 (%)                                                                                        1
# 10. Households using iodized salt (%)                                                                                                  1
# 11. Households with any usual member covered by a health scheme or health insurance (%)                                                1
# 12. Women who are literate (%)                                                                                                         1
# 13. Men who are literate (%)                                                                                                          65
# 14. Women with 10 or more years of schooling (%)                                                                                       1
# 15. Women age 20-24 years married before age 18 years (%)                                                                             63
# 17. Women age 15-19 years who were already mothers or pregnant at the time of the survey (%)                                          67
# 18. Any method (%)                                                                                                                     4
# 19. Any modern method (%)                                                                                                              4
# 20. Female sterilization (%)                                                                                                           4
# 21. Male sterilization (%)                                                                                                             4
# 22. IUD/PPIUD (%)                                                                                                                      4
# 23. Pill (%)                                                                                                                           4
# 24. Condom (%)                                                                                                                         4
# 25. Total unmet need (%)                                                                                                               4
# 26. Unmet need for spacing (%)                                                                                                         4
# 27. Health worker ever talked to female non-users about family planning5 (%)                                                           8
# 28. Current users ever told about side effects of current method (%)                                                                 174
# 29. Mothers who had antenatal check-up in the first trimester (%)                                                                     39
# 30. Mothers who had at least 4 antenatal care visits (%)                                                                              39
# 31. Mothers whose last birth was protected against neonatal tetanus6 (%)                                                              39
# 32. Mothers who consumed iron folic acid for 100 days or more when they were pregnant (%)                                             39
# 33. Mothers who had full antenatal care7 (%)                                                                                          39
# 34. Registered pregnancies for which the mother received Mother and Child Protection (MCP) card (%)                                   65
# 35. Mothers who received postnatal care from a doctor/nurse/LHV/ANM/midwife/other health personnel within 2 days of delivery (%)      39
# 36. Mothers who received financial assistance under Janani Suraksha Yojana (JSY) for births delivered in an institution (%)           59
# 37. Average out of pocket expenditure per delivery in public health facility (Rs.)                                                   143
# 39. Children who received postnatal care from a doctor/nurse/LHV/ANM/midwife/other health personnel within 2 days of delivery (%)     39
# 40. Institutional births (%)                                                                                                          28
# 41. Institutional births in public facility (%)                                                                                       28
# 42. Home delivery conducted by skilled health personnel (out of total deliveries) (%)                                                 28
# 43. Births assisted by a doctor/nurse/LHV/ANM/other health personnel (%)                                                              28
# 44. Births delivered by caesarean section (%)                                                                                         28
# 46. Births in a public health facility delivered by caesarean section (%)                                                             85
# 47. Children age 12-23 months fully immunized (BCG measles and 3 doses each of polio/DPT) (%)                                        242
# 48. Children age 12-23 months who have received BCG (%)                                                                              242
# 49. Children age 12-23 months who have received 3 doses of polio vaccine (%)                                                         242
# 50. Children age 12-23 months who have received 3 doses of DPT vaccine (%)                                                           242
# 51. Children age 12-23 months who have received measles vaccine (%)                                                                  242
# 52. Children age 12-23 months who have received 3 doses of Hepatitis B vaccine (%)                                                   242
# 53. Children age 9-59 months who received a vitamin A dose in last 6 months (%)                                                       41
# 54. Children age 12-23 months who received most of the vaccinations in public health facility (%)                                    254
# 55. Children age 12-23 months who received most of the vaccinations in private health facility (%)                                   254
# 56. Prevalence of diarrhoea (reported) in the last 2 weeks preceding the survey (%)                                                   31
# 60. Prevalence of symptoms of acute respiratory infection (ARI) in the last 2 weeks preceding the survey (%)                          31
# 62. Children under age 3 years breastfed within one hour of birth8 (%)                                                                70
# 65. Breastfeeding children age 6-23 months receiving an adequate diet9 10 (%)                                                        209
# 67. Total children age 6-23 months receiving an adequate diet9 10 (%)                                                                136
# 68. Children under 5 years who are stunted11 (%)                                                                                      37
# 69. Children under 5 years who are wasted11 (%)                                                                                       37
# 70. Children under 5 years who are severely wasted12 (%)                                                                              37
# 71. Children under 5 years who are underweight11 (%)                                                                                  37
# 72. Women whose Body Mass Index (BMI) is below normal (BMI <18.5 kg/m2) (%)                                                            2
# 73. Men whose Body Mass Index (BMI) is below normal (BMI <18.5 kg/m2) (%)                                                             69
# 74. Women who are overweight or obese (BMI >=25.0 kg/m2) (%)                                                                           2
# 75. Men who are overweight or obese (BMI >=25.0 kg/m2) (%)                                                                            69
# 76. Children age 6-59 months who are anaemic (<11.0 g/dl) (%)                                                                         41
# 77. Non-pregnant women age 15-49 years who are anaemic (<12.0 g/dl) (%)                                                                2
# 79. All women age 15-49 years who are anaemic (%)                                                                                      2
# 80. Men age 15-49 years who are anaemic (<13.0 g/dl) (%)                                                                              70
# 81. Blood sugar level - high (>140 mg/dl) (%)                                                                                          2
# 82. Blood sugar level - very high (>160 mg/dl) (%)                                                                                     2
# 83. Blood sugar level - high (>140 mg/dl) (%)                                                                                         70
# 84. Blood sugar level - very high (>160 mg/dl) (%)                                                                                    70
# 85. Slightly above normal (Systolic 140-159 mm of Hg and/or Diastolic 90-99 mm of Hg) (%)                                              3
# 86. Moderately high (Systolic 160-179 mm of Hg and/or Diastolic 100-109 mm of Hg) (%)                                                  3
# 87. Very high (Systolic ?180 mm of Hg and/or Diastolic ?110 mm of Hg) (%)                                                              3
# 88. Slightly above normal (Systolic 140-159 mm of Hg and/or Diastolic 90-99 mm of Hg) (%)                                             69
# 89. Moderately high (Systolic 160-179 mm of Hg and/or Diastolic 100-109 mm of Hg) (%)                                                 69
# 90. Very high (Systolic ?180 mm of Hg and/or Diastolic ?110 mm of Hg) (%)                                                             69
# 91. Cervix (%)                                                                                                                         1
# 92. Breast (%)                                                                                                                         1
# 93. Oral cavity (%)                                                                                                                    1
# State                                                                                                                                  0
# Region                                                                                                                                 0
# Zone                                                                                                                                   0
# dtype: int64

# %%
for col in dataset3.columns:
     if col in attribute_categories['family_planning']:
        print("'"+col+"'")
# Out:
# '18. Any method (%)'
# '19. Any modern method (%)'
# '20. Female sterilization (%)'
# '21. Male sterilization (%)'
# '22. IUD/PPIUD (%)'
# '23. Pill (%)'
# '24. Condom (%)'
# '25. Total unmet need (%)'
# '26. Unmet need for spacing (%)'

# %%
dataset3=dataset3.drop(['18. Any method (%)',
'20. Female sterilization (%)',
'21. Male sterilization (%)',
'22. IUD/PPIUD (%)',
'23. Pill (%)',
'24. Condom (%)',
'26. Unmet need for spacing (%)'], axis=1)

# %%
for col in dataset3.columns:
     if col in attribute_categories['maternity_care']:
        print("'"+col+"'")
#         print(dataset3[col].corr(dataset3['68. Children under 5 years who are stunted11 (%)']))
# Out:
# '29. Mothers who had antenatal check-up in the first trimester (%)'
# '30. Mothers who had at least 4 antenatal care visits (%)'
# '31. Mothers whose last birth was protected against neonatal tetanus6 (%)'
# '32. Mothers who consumed iron folic acid for 100 days or more when they were pregnant (%)'
# '33. Mothers who had full antenatal care7 (%)'
# '35. Mothers who received postnatal care from a doctor/nurse/LHV/ANM/midwife/other health personnel within 2 days of delivery (%)'
# '39. Children who received postnatal care from a doctor/nurse/LHV/ANM/midwife/other health personnel within 2 days of delivery (%)'

# %%
dataset3=dataset3.drop(['29. Mothers who had antenatal check-up in the first trimester (%)',
'31. Mothers whose last birth was protected against neonatal tetanus6 (%)',
'33. Mothers who had full antenatal care7 (%)',
'35. Mothers who received postnatal care from a doctor/nurse/LHV/ANM/midwife/other health personnel within 2 days of delivery (%)',
'39. Children who received postnatal care from a doctor/nurse/LHV/ANM/midwife/other health personnel within 2 days of delivery (%)'], axis=1)

# %%
for col in dataset3.columns:
     if col in attribute_categories['delivery_care']:
        print("'"+col+"'")
        #print(dataset3[col].corr(dataset3['68. Children under 5 years who are stunted11 (%)']))
# Out:
# '40. Institutional births (%)'
# '41. Institutional births in public facility (%)'
# '42. Home delivery conducted by skilled health personnel (out of total deliveries) (%)'
# '43. Births assisted by a doctor/nurse/LHV/ANM/other health personnel (%)'
# '44. Births delivered by caesarean section (%)'
# '46. Births in a public health facility delivered by caesarean section (%)'

# %%
dataset3=dataset3.drop(['41. Institutional births in public facility (%)',
'42. Home delivery conducted by skilled health personnel (out of total deliveries) (%)',
'43. Births assisted by a doctor/nurse/LHV/ANM/other health personnel (%)',
'44. Births delivered by caesarean section (%)',
'46. Births in a public health facility delivered by caesarean section (%)'], axis=1)

# %%
for col in dataset3.columns:
     if col in attribute_categories['child_immunisation']:
        print("'"+col+"'")
        #print(dataset3[col].corr(dataset3['68. Children under 5 years who are stunted11 (%)']))
# Out:
# '47. Children age 12-23 months fully immunized (BCG measles and 3 doses each of polio/DPT) (%)'
# '48. Children age 12-23 months who have received BCG (%)'
# '49. Children age 12-23 months who have received 3 doses of polio vaccine (%)'
# '50. Children age 12-23 months who have received 3 doses of DPT vaccine (%)'
# '51. Children age 12-23 months who have received measles vaccine (%)'
# '52. Children age 12-23 months who have received 3 doses of Hepatitis B vaccine (%)'
# '53. Children age 9-59 months who received a vitamin A dose in last 6 months (%)'
# '54. Children age 12-23 months who received most of the vaccinations in public health facility (%)'
# '55. Children age 12-23 months who received most of the vaccinations in private health facility (%)'

# %%
dataset3=dataset3.drop(['48. Children age 12-23 months who have received BCG (%)',
'49. Children age 12-23 months who have received 3 doses of polio vaccine (%)',
'50. Children age 12-23 months who have received 3 doses of DPT vaccine (%)',
'51. Children age 12-23 months who have received measles vaccine (%)',
'52. Children age 12-23 months who have received 3 doses of Hepatitis B vaccine (%)',
'54. Children age 12-23 months who received most of the vaccinations in public health facility (%)',
'55. Children age 12-23 months who received most of the vaccinations in private health facility (%)',
], axis=1)

# %%
attribute_categories.keys()
# Out:
# dict_keys(['population', 'literacy', 'marriage', 'family_planning', 'maternity_care', 'delivery_care', 'child_immunisation', 'childhood_diseases', 'child_nutrition', 'adult_nutrition', 'anaemia', 'blood_sugar_level', 'hypertension', 'women_examination'])

# %%
for col in dataset3.columns:
     if col in attribute_categories['child_nutrition']:
        print("'"+col+"'")
        #print(dataset3[col].corr(dataset3['68. Children under 5 years who are stunted11 (%)']))
# Out:
# '62. Children under age 3 years breastfed within one hour of birth8 (%)'
# '65. Breastfeeding children age 6-23 months receiving an adequate diet9 10 (%)'
# '67. Total children age 6-23 months receiving an adequate diet9 10 (%)'
# '68. Children under 5 years who are stunted11 (%)'
# '69. Children under 5 years who are wasted11 (%)'
# '70. Children under 5 years who are severely wasted12 (%)'
# '71. Children under 5 years who are underweight11 (%)'

# %%
dataset3=dataset3.drop(['69. Children under 5 years who are wasted11 (%)',
'70. Children under 5 years who are severely wasted12 (%)',
'71. Children under 5 years who are underweight11 (%)',
], axis=1)

# %%
for col in dataset3.columns:
     if col in attribute_categories['anaemia']:
        print("'"+col+"'")
        print(dataset3[col].corr(dataset3['68. Children under 5 years who are stunted11 (%)']))
# Out:
# '76. Children age 6-59 months who are anaemic (<11.0 g/dl) (%)'
# 0.38306714619873306
# '77. Non-pregnant women age 15-49 years who are anaemic (<12.0 g/dl) (%)'
# 0.2768658055712757
# '79. All women age 15-49 years who are anaemic (%)'
# 0.2828934930488913
# '80. Men age 15-49 years who are anaemic (<13.0 g/dl) (%)'
# 0.32816338673036644

# %%
dataset3=dataset3.drop(['77. Non-pregnant women age 15-49 years who are anaemic (<12.0 g/dl) (%)'
], axis=1)

# %%
len(dataset3.columns)
# Out:
# 36

# %%
dataset3.corr()['68. Children under 5 years who are stunted11 (%)']
# Out:
# 1. Population (female) age 6+ years who ever attended school (%)                                -0.577464
# 3. Sex ratio of the total population (females per 1000 males)                                    0.008757
# 4. Sex ratio at birth for children born in the last five years (females per 1000 males)         -0.029723
# 6. Households with electricity (%)                                                              -0.586164
# 7. Households with an improved drinking-water source1 (%)                                        0.005558
# 8. Households using improved sanitation facility2 (%)                                           -0.607010
# 9. Households using clean fuel for cooking3 (%)                                                 -0.520680
# 10. Households using iodized salt (%)                                                           -0.112023
# 11. Households with any usual member covered by a health scheme or health insurance (%)         -0.291284
# 12. Women who are literate (%)                                                                  -0.650422
# 13. Men who are literate (%)                                                                    -0.514971
# 14. Women with 10 or more years of schooling (%)                                                -0.591046
# 15. Women age 20-24 years married before age 18 years (%)                                        0.538721
# 17. Women age 15-19 years who were already mothers or pregnant at the time of the survey (%)     0.268249
# 19. Any modern method (%)                                                                       -0.269643
# 25. Total unmet need (%)                                                                         0.214041
# 30. Mothers who had at least 4 antenatal care visits (%)                                        -0.572111
# 32. Mothers who consumed iron folic acid for 100 days or more when they were pregnant (%)       -0.490050
# 40. Institutional births (%)                                                                    -0.455087
# 47. Children age 12-23 months fully immunized (BCG measles and 3 doses each of polio/DPT) (%)   -0.290314
# 53. Children age 9-59 months who received a vitamin A dose in last 6 months (%)                 -0.299153
# 62. Children under age 3 years breastfed within one hour of birth8 (%)                          -0.277880
# 65. Breastfeeding children age 6-23 months receiving an adequate diet9 10 (%)                   -0.369382
# 67. Total children age 6-23 months receiving an adequate diet9 10 (%)                           -0.412613
# 68. Children under 5 years who are stunted11 (%)                                                 1.000000
# 72. Women whose Body Mass Index (BMI) is below normal (BMI <18.5 kg/m2) (%)                      0.633503
# 73. Men whose Body Mass Index (BMI) is below normal (BMI <18.5 kg/m2) (%)                        0.552667
# 74. Women who are overweight or obese (BMI >=25.0 kg/m2) (%)                                    -0.636356
# 75. Men who are overweight or obese (BMI >=25.0 kg/m2) (%)                                      -0.573015
# 76. Children age 6-59 months who are anaemic (<11.0 g/dl) (%)                                    0.383067
# 79. All women age 15-49 years who are anaemic (%)                                                0.282893
# 80. Men age 15-49 years who are anaemic (<13.0 g/dl) (%)                                         0.328163
# Name: 68. Children under 5 years who are stunted11 (%), dtype: float64

# %%
dataset3=dataset3.drop(['3. Sex ratio of the total population (females per 1000 males)',
                        '6. Households with electricity (%)', '11. Households with any usual member covered by a health scheme or health insurance (%)',
                        '17. Women age 15-19 years who were already mothers or pregnant at the time of the survey (%)'
], axis=1)

# %%
dataset3.shape
# Out:
# (913, 32)

# %%
dataset3.isna().sum().sum()
# Out:
# 1315

# %%
1315/(913*32)
# Out:
# 0.04500958378970427

# %%
dataset3.isna().sum()
# Out:
# District                                                                                           0
# 1. Population (female) age 6+ years who ever attended school (%)                                   0
# 4. Sex ratio at birth for children born in the last five years (females per 1000 males)           77
# 7. Households with an improved drinking-water source1 (%)                                          1
# 8. Households using improved sanitation facility2 (%)                                              1
# 9. Households using clean fuel for cooking3 (%)                                                    1
# 10. Households using iodized salt (%)                                                              1
# 12. Women who are literate (%)                                                                     1
# 13. Men who are literate (%)                                                                      65
# 14. Women with 10 or more years of schooling (%)                                                   1
# 15. Women age 20-24 years married before age 18 years (%)                                         63
# 19. Any modern method (%)                                                                          4
# 25. Total unmet need (%)                                                                           4
# 30. Mothers who had at least 4 antenatal care visits (%)                                          39
# 32. Mothers who consumed iron folic acid for 100 days or more when they were pregnant (%)         39
# 40. Institutional births (%)                                                                      28
# 47. Children age 12-23 months fully immunized (BCG measles and 3 doses each of polio/DPT) (%)    242
# 53. Children age 9-59 months who received a vitamin A dose in last 6 months (%)                   41
# 62. Children under age 3 years breastfed within one hour of birth8 (%)                            70
# 65. Breastfeeding children age 6-23 months receiving an adequate diet9 10 (%)                    209
# 67. Total children age 6-23 months receiving an adequate diet9 10 (%)                            136
# 68. Children under 5 years who are stunted11 (%)                                                  37
# 72. Women whose Body Mass Index (BMI) is below normal (BMI <18.5 kg/m2) (%)                        2
# 73. Men whose Body Mass Index (BMI) is below normal (BMI <18.5 kg/m2) (%)                         69
# 74. Women who are overweight or obese (BMI >=25.0 kg/m2) (%)                                       2
# 75. Men who are overweight or obese (BMI >=25.0 kg/m2) (%)                                        69
# 76. Children age 6-59 months who are anaemic (<11.0 g/dl) (%)                                     41
# 79. All women age 15-49 years who are anaemic (%)                                                  2
# 80. Men age 15-49 years who are anaemic (<13.0 g/dl) (%)                                          70
# State                                                                                              0
# Region                                                                                             0
# Zone                                                                                               0
# dtype: int64

# %%
dataset3=dataset3.dropna(axis=0,how='any',inplace=False)
dataset3
# Out:
#            District  \
# 0          Senapati
# 2        Tamenglong
# 4     Churachandpur
# 6         Bishnupur
# 7         Bishnupur
# ...             ...
# 1540       Longleng
# 1542        Kiphire
# 1544         Kohima
# 1545         Kohima
# 1547          Peren
#
#       1. Population (female) age 6+ years who ever attended school (%)  \
# 0                                                  79.7
# 2                                                  69.5
# 4                                                  79.4
# 6                                                  82.3
# 7                                                  77.4
# ...                                                 ...
# 1540                                               77.9
# 1542                                               72.2
# 1544                                               91.9
# 1545                                               78.2
# 1547                                               75.6
#
#       4. Sex ratio at birth for children born in the last five years (females per 1000 males)  \
# 0                                                 856.0
# 2                                                1158.0
# 4                                                 998.0
# 6                                                 915.0
# 7                                                 916.0
# ...                                                 ...
# 1540                                              773.0
# 1542                                              964.0
# 1544                                             1139.0
# 1545                                             1135.0
# 1547                                              937.0
#
#       7. Households with an improved drinking-water source1 (%)  \
# 0                                                  36.4
# 2                                                  36.7
# 4                                                  49.6
# 6                                                  44.6
# 7                                                  43.0
# ...                                                 ...
# 1540                                               43.0
# 1542                                               89.3
# 1544                                               81.5
# 1545                                               77.4
# 1547                                               64.5
#
#       8. Households using improved sanitation facility2 (%)  \
# 0                                                  59.5
# 2                                                  61.0
# 4                                                  66.0
# 6                                                  35.7
# 7                                                  40.9
# ...                                                 ...
# 1540                                               75.1
# 1542                                               85.9
# 1544                                               65.9
# 1545                                               73.5
# 1547                                               73.5
#
#       9. Households using clean fuel for cooking3 (%)  \
# 0                                                16.8
# 2                                                 7.3
# 4                                                40.0
# 6                                                46.3
# 7                                                30.7
# ...                                               ...
# 1540                                              1.8
# 1542                                              4.9
# 1544                                             84.4
# 1545                                             14.4
# 1547                                             11.3
#
#       10. Households using iodized salt (%)  12. Women who are literate (%)  \
# 0                                      98.5                            79.5
# 2                                      99.6                            65.4
# 4                                     100.0                            80.6
# 6                                      99.7                            87.4
# 7                                      99.9                            83.9
# ...                                     ...                             ...
# 1540                                   99.8                            73.9
# 1542                                   99.0                            69.1
# 1544                                   99.6                            92.7
# 1545                                   99.0                            83.7
# 1547                                   99.9                            72.1
#
#       13. Men who are literate (%)  \
# 0                             93.1
# 2                             90.2
# 4                             93.6
# 6                             95.2
# 7                             94.7
# ...                            ...
# 1540                          82.8
# 1542                          80.7
# 1544                          90.0
# 1545                          86.0
# 1547                          85.5
#
#       14. Women with 10 or more years of schooling (%)  ...  \
# 0                                                 33.5  ...
# 2                                                 23.1  ...
# 4                                                 36.6  ...
# 6                                                 49.6  ...
# 7                                                 35.8  ...
# ...                                                ...  ...
# 1540                                              13.8  ...
# 1542                                              13.8  ...
# 1544                                              62.4  ...
# 1545                                              25.3  ...
# 1547                                              17.2  ...
#
#       72. Women whose Body Mass Index (BMI) is below normal (BMI <18.5 kg/m2) (%)  \
# 0                                                   9.2
# 2                                                   7.2
# 4                                                   8.1
# 6                                                  11.8
# 7                                                  10.1
# ...                                                 ...
# 1540                                               14.6
# 1542                                               11.3
# 1544                                               10.5
# 1545                                               10.8
# 1547                                                7.5
#
#       73. Men whose Body Mass Index (BMI) is below normal (BMI <18.5 kg/m2) (%)  \
# 0                                                   7.1
# 2                                                   3.9
# 4                                                   5.6
# 6                                                  11.8
# 7                                                  13.6
# ...                                                 ...
# 1540                                               12.6
# 1542                                                9.4
# 1544                                               16.4
# 1545                                                4.7
# 1547                                               10.3
#
#       74. Women who are overweight or obese (BMI >=25.0 kg/m2) (%)  \
# 0                                                  18.9
# 2                                                  11.6
# 4                                                  22.0
# 6                                                  25.5
# 7                                                  23.4
# ...                                                 ...
# 1540                                                6.1
# 1542                                                8.4
# 1544                                               21.1
# 1545                                               18.9
# 1547                                               15.7
#
#       75. Men who are overweight or obese (BMI >=25.0 kg/m2) (%)  \
# 0                                                  18.8
# 2                                                   8.3
# 4                                                  17.1
# 6                                                  23.1
# 7                                                  20.5
# ...                                                 ...
# 1540                                                5.8
# 1542                                                7.8
# 1544                                               23.6
# 1545                                               19.5
# 1547                                                7.3
#
#       76. Children age 6-59 months who are anaemic (<11.0 g/dl) (%)  \
# 0                                                  23.3
# 2                                                  22.9
# 4                                                  18.4
# 6                                                  22.3
# 7                                                  20.6
# ...                                                 ...
# 1540                                               13.1
# 1542                                               18.6
# 1544                                               27.6
# 1545                                               29.1
# 1547                                               15.2
#
#       79. All women age 15-49 years who are anaemic (%)  \
# 0                                                  25.2
# 2                                                  27.2
# 4                                                  20.3
# 6                                                  23.6
# 7                                                  30.1
# ...                                                 ...
# 1540                                               19.6
# 1542                                               22.0
# 1544                                               18.6
# 1545                                               21.4
# 1547                                               19.5
#
#       80. Men age 15-49 years who are anaemic (<13.0 g/dl) (%)  State  Region  \
# 0                                                   5.9            MN   Rural
# 2                                                  13.9            MN   Rural
# 4                                                   4.9            MN   Rural
# 6                                                   7.6            MN   Urban
# 7                                                  11.9            MN   Rural
# ...                                                 ...           ...     ...
# 1540                                                4.4            NL   Rural
# 1542                                                2.3            NL   Rural
# 1544                                               10.6            NL   Urban
# 1545                                               14.5            NL   Rural
# 1547                                               11.7            NL   Rural
#
#                     Zone
# 0     North Eastern Zone
# 2     North Eastern Zone
# 4     North Eastern Zone
# 6     North Eastern Zone
# 7     North Eastern Zone
# ...                  ...
# 1540  North Eastern Zone
# 1542  North Eastern Zone
# 1544  North Eastern Zone
# 1545  North Eastern Zone
# 1547  North Eastern Zone
#
# [654 rows x 32 columns]

# %%
dataset3.isna().sum().sum()
# Out:
# 0

# %%
dataset3.to_csv('./../Data/working_data/cleaned_data_3.csv',index=False)

# %% [markdown]
# ## DATA PREPROCESSING: Z-Score Normalisation/Standardisation

# %%
to_ignore = ['District', 'State', 'Region', 'Zone']
for col in dataset3.columns:
    if col not in to_ignore:
        dataset3[col]=(dataset3[col] - dataset3[col].mean())/dataset3[col].std()

# %%
dataset3
# Out:
#            District  \
# 0          Senapati
# 2        Tamenglong
# 4     Churachandpur
# 6         Bishnupur
# 7         Bishnupur
# ...             ...
# 1540       Longleng
# 1542        Kiphire
# 1544         Kohima
# 1545         Kohima
# 1547          Peren
#
#       1. Population (female) age 6+ years who ever attended school (%)  \
# 0                                              1.091826
# 2                                              0.240678
# 4                                              1.066792
# 6                                              1.308785
# 7                                              0.899900
# ...                                                 ...
# 1540                                           0.941623
# 1542                                           0.465982
# 1544                                           2.109866
# 1545                                           0.966657
# 1547                                           0.749698
#
#       4. Sex ratio at birth for children born in the last five years (females per 1000 males)  \
# 0                                             -0.600907
# 2                                              1.818615
# 4                                              0.536749
# 6                                             -0.128219
# 7                                             -0.120207
# ...                                                 ...
# 1540                                          -1.265875
# 1542                                           0.264353
# 1544                                           1.666394
# 1545                                           1.634347
# 1547                                           0.048038
#
#       7. Households with an improved drinking-water source1 (%)  \
# 0                                             -3.643660
# 2                                             -3.622292
# 4                                             -2.703441
# 6                                             -3.059584
# 7                                             -3.173550
# ...                                                 ...
# 1540                                          -3.173550
# 1542                                           0.124342
# 1544                                          -0.431242
# 1545                                          -0.723280
# 1547                                          -1.642132
#
#       8. Households using improved sanitation facility2 (%)  \
# 0                                              0.621613
# 2                                              0.682138
# 4                                              0.883891
# 6                                             -0.338728
# 7                                             -0.128905
# ...                                                 ...
# 1540                                           1.251080
# 1542                                           1.686865
# 1544                                           0.879856
# 1545                                           1.186519
# 1547                                           1.186519
#
#       9. Households using clean fuel for cooking3 (%)  \
# 0                                           -0.529196
# 2                                           -0.869819
# 4                                            0.302640
# 6                                            0.528526
# 7                                           -0.030812
# ...                                               ...
# 1540                                        -1.067021
# 1542                                        -0.955871
# 1544                                         1.894602
# 1545                                        -0.615248
# 1547                                        -0.726399
#
#       10. Households using iodized salt (%)  12. Women who are literate (%)  \
# 0                                  0.627384                        0.871001
# 2                                  0.784194                       -0.021019
# 4                                  0.841216                        0.940591
# 6                                  0.798449                        1.370785
# 7                                  0.826960                        1.149362
# ...                                     ...                             ...
# 1540                               0.812705                        0.516723
# 1542                               0.698661                        0.213057
# 1544                               0.784194                        1.706084
# 1545                               0.698661                        1.136709
# 1547                               0.826960                        0.402849
#
#       13. Men who are literate (%)  \
# 0                         0.962369
# 2                         0.660140
# 4                         1.014478
# 6                         1.181225
# 7                         1.129117
# ...                            ...
# 1540                     -0.111066
# 1542                     -0.329922
# 1544                      0.639297
# 1545                      0.222428
# 1547                      0.170320
#
#       14. Women with 10 or more years of schooling (%)  ...  \
# 0                                             0.159715  ...
# 2                                            -0.517406  ...
# 4                                             0.361549  ...
# 6                                             1.207951  ...
# 7                                             0.309463  ...
# ...                                                ...  ...
# 1540                                         -1.122908  ...
# 1542                                         -1.122908  ...
# 1544                                          2.041330  ...
# 1545                                         -0.374169  ...
# 1547                                         -0.901542  ...
#
#       72. Women whose Body Mass Index (BMI) is below normal (BMI <18.5 kg/m2) (%)  \
# 0                                             -1.468186
# 2                                             -1.675713
# 4                                             -1.582326
# 6                                             -1.198401
# 7                                             -1.374799
# ...                                                 ...
# 1540                                          -0.907863
# 1542                                          -1.250283
# 1544                                          -1.333293
# 1545                                          -1.302164
# 1547                                          -1.644584
#
#       73. Men whose Body Mass Index (BMI) is below normal (BMI <18.5 kg/m2) (%)  \
# 0                                             -1.423069
# 2                                             -1.761707
# 4                                             -1.581805
# 6                                             -0.925694
# 7                                             -0.735211
# ...                                                 ...
# 1540                                          -0.841035
# 1542                                          -1.179673
# 1544                                          -0.438902
# 1545                                          -1.677047
# 1547                                          -1.084431
#
#       74. Women who are overweight or obese (BMI >=25.0 kg/m2) (%)  \
# 0                                              0.229377
# 2                                             -0.548706
# 4                                              0.559795
# 6                                              0.932849
# 7                                              0.709017
# ...                                                 ...
# 1540                                          -1.134933
# 1542                                          -0.889784
# 1544                                           0.463867
# 1545                                           0.229377
# 1547                                          -0.111701
#
#       75. Men who are overweight or obese (BMI >=25.0 kg/m2) (%)  \
# 0                                              0.402776
# 2                                             -0.768554
# 4                                              0.213132
# 6                                              0.882463
# 7                                              0.592420
# ...                                                 ...
# 1540                                          -1.047442
# 1542                                          -0.824332
# 1544                                           0.938241
# 1545                                           0.480865
# 1547                                          -0.880109
#
#       76. Children age 6-59 months who are anaemic (<11.0 g/dl) (%)  \
# 0                                             -2.034383
# 2                                             -2.058899
# 4                                             -2.334704
# 6                                             -2.095673
# 7                                             -2.199866
# ...                                                 ...
# 1540                                          -2.659542
# 1542                                          -2.322446
# 1544                                          -1.770835
# 1545                                          -1.678900
# 1547                                          -2.530832
#
#       79. All women age 15-49 years who are anaemic (%)  \
# 0                                             -1.990100
# 2                                             -1.836526
# 4                                             -2.366356
# 6                                             -2.112959
# 7                                             -1.613844
# ...                                                 ...
# 1540                                          -2.420106
# 1542                                          -2.235818
# 1544                                          -2.496893
# 1545                                          -2.281890
# 1547                                          -2.427785
#
#       80. Men age 15-49 years who are anaemic (<13.0 g/dl) (%)  State  Region  \
# 0                                             -1.656464            MN   Rural
# 2                                             -0.895709            MN   Rural
# 4                                             -1.751558            MN   Rural
# 6                                             -1.494803            MN   Urban
# 7                                             -1.085898            MN   Rural
# ...                                                 ...           ...     ...
# 1540                                          -1.799105            NL   Rural
# 1542                                          -1.998804            NL   Rural
# 1544                                          -1.209520            NL   Urban
# 1545                                          -0.838652            NL   Rural
# 1547                                          -1.104917            NL   Rural
#
#                     Zone
# 0     North Eastern Zone
# 2     North Eastern Zone
# 4     North Eastern Zone
# 6     North Eastern Zone
# 7     North Eastern Zone
# ...                  ...
# 1540  North Eastern Zone
# 1542  North Eastern Zone
# 1544  North Eastern Zone
# 1545  North Eastern Zone
# 1547  North Eastern Zone
#
# [654 rows x 32 columns]

# %%
len(dataset3.columns)
# Out:
# 32

# %%
dataset3.to_csv('./../Data/working_data/normalised_data_4.csv')

# %% [markdown]
# ## DATA PREPROCESSING: Unsupervised Discretisation : Equal Interval Binning

# %%
dataset4=dataset3.copy()
to_ignore = ['District', 'State', 'Region', 'Zone']
for col in dataset4.columns:
    if col not in to_ignore:
        dataset4[col]=pd.cut(dataset4[col],3,labels=['low', 'medium', 'high'])

# %%
dataset4
# Out:
#            District  \
# 0          Senapati
# 2        Tamenglong
# 4     Churachandpur
# 6         Bishnupur
# 7         Bishnupur
# ...             ...
# 1540       Longleng
# 1542        Kiphire
# 1544         Kohima
# 1545         Kohima
# 1547          Peren
#
#      1. Population (female) age 6+ years who ever attended school (%)  \
# 0                                                  high
# 2                                                medium
# 4                                                  high
# 6                                                  high
# 7                                                  high
# ...                                                 ...
# 1540                                               high
# 1542                                             medium
# 1544                                               high
# 1545                                               high
# 1547                                             medium
#
#      4. Sex ratio at birth for children born in the last five years (females per 1000 males)  \
# 0                                                   low
# 2                                                medium
# 4                                                medium
# 6                                                   low
# 7                                                   low
# ...                                                 ...
# 1540                                                low
# 1542                                             medium
# 1544                                             medium
# 1545                                             medium
# 1547                                             medium
#
#      7. Households with an improved drinking-water source1 (%)  \
# 0                                                   low
# 2                                                   low
# 4                                                   low
# 6                                                   low
# 7                                                   low
# ...                                                 ...
# 1540                                                low
# 1542                                               high
# 1544                                               high
# 1545                                               high
# 1547                                             medium
#
#      8. Households using improved sanitation facility2 (%)  \
# 0                                                medium
# 2                                                medium
# 4                                                medium
# 6                                                medium
# 7                                                medium
# ...                                                 ...
# 1540                                               high
# 1542                                               high
# 1544                                             medium
# 1545                                               high
# 1547                                               high
#
#      9. Households using clean fuel for cooking3 (%)  \
# 0                                                low
# 2                                                low
# 4                                             medium
# 6                                             medium
# 7                                                low
# ...                                              ...
# 1540                                             low
# 1542                                             low
# 1544                                            high
# 1545                                             low
# 1547                                             low
#
#      10. Households using iodized salt (%) 12. Women who are literate (%)  \
# 0                                     high                           high
# 2                                     high                         medium
# 4                                     high                           high
# 6                                     high                           high
# 7                                     high                           high
# ...                                    ...                            ...
# 1540                                  high                           high
# 1542                                  high                         medium
# 1544                                  high                           high
# 1545                                  high                           high
# 1547                                  high                         medium
#
#      13. Men who are literate (%)  \
# 0                            high
# 2                            high
# 4                            high
# 6                            high
# 7                            high
# ...                           ...
# 1540                         high
# 1542                       medium
# 1544                         high
# 1545                         high
# 1547                         high
#
#      14. Women with 10 or more years of schooling (%)  ...  \
# 0                                              medium  ...
# 2                                                 low  ...
# 4                                              medium  ...
# 6                                              medium  ...
# 7                                              medium  ...
# ...                                               ...  ...
# 1540                                              low  ...
# 1542                                              low  ...
# 1544                                             high  ...
# 1545                                              low  ...
# 1547                                              low  ...
#
#      72. Women whose Body Mass Index (BMI) is below normal (BMI <18.5 kg/m2) (%)  \
# 0                                                   low
# 2                                                   low
# 4                                                   low
# 6                                                   low
# 7                                                   low
# ...                                                 ...
# 1540                                                low
# 1542                                                low
# 1544                                                low
# 1545                                                low
# 1547                                                low
#
#      73. Men whose Body Mass Index (BMI) is below normal (BMI <18.5 kg/m2) (%)  \
# 0                                                   low
# 2                                                   low
# 4                                                   low
# 6                                                   low
# 7                                                   low
# ...                                                 ...
# 1540                                                low
# 1542                                                low
# 1544                                                low
# 1545                                                low
# 1547                                                low
#
#      74. Women who are overweight or obese (BMI >=25.0 kg/m2) (%)  \
# 0                                                medium
# 2                                                   low
# 4                                                medium
# 6                                                medium
# 7                                                medium
# ...                                                 ...
# 1540                                                low
# 1542                                                low
# 1544                                             medium
# 1545                                             medium
# 1547                                                low
#
#      75. Men who are overweight or obese (BMI >=25.0 kg/m2) (%)  \
# 0                                                medium
# 2                                                   low
# 4                                                   low
# 6                                                medium
# 7                                                medium
# ...                                                 ...
# 1540                                                low
# 1542                                                low
# 1544                                             medium
# 1545                                             medium
# 1547                                                low
#
#      76. Children age 6-59 months who are anaemic (<11.0 g/dl) (%)  \
# 0                                                   low
# 2                                                   low
# 4                                                   low
# 6                                                   low
# 7                                                   low
# ...                                                 ...
# 1540                                                low
# 1542                                                low
# 1544                                                low
# 1545                                                low
# 1547                                                low
#
#      79. All women age 15-49 years who are anaemic (%)  \
# 0                                                  low
# 2                                                  low
# 4                                                  low
# 6                                                  low
# 7                                                  low
# ...                                                ...
# 1540                                               low
# 1542                                               low
# 1544                                               low
# 1545                                               low
# 1547                                               low
#
#      80. Men age 15-49 years who are anaemic (<13.0 g/dl) (%) State Region  \
# 0                                                   low          MN  Rural
# 2                                                   low          MN  Rural
# 4                                                   low          MN  Rural
# 6                                                   low          MN  Urban
# 7                                                   low          MN  Rural
# ...                                                 ...         ...    ...
# 1540                                                low          NL  Rural
# 1542                                                low          NL  Rural
# 1544                                                low          NL  Urban
# 1545                                                low          NL  Rural
# 1547                                                low          NL  Rural
#
#                     Zone
# 0     North Eastern Zone
# 2     North Eastern Zone
# 4     North Eastern Zone
# 6     North Eastern Zone
# 7     North Eastern Zone
# ...                  ...
# 1540  North Eastern Zone
# 1542  North Eastern Zone
# 1544  North Eastern Zone
# 1545  North Eastern Zone
# 1547  North Eastern Zone
#
# [654 rows x 32 columns]

# %%
dataset4.to_csv('./../Data/working_data/equal_interval_discretised_data_5.csv')

# %% [markdown]
# ## DATA PREPROCESSING: Unsupervised Discretisation : Equal Frequency Binning

# %%
dataset5=dataset3.copy()
to_ignore = ['District', 'Households surveyed', 'Women age 15-49 years interviewed',
       'Men age 15-49 years interviewed', 'State', 'Region', 'Zone']
for col in dataset5.columns:
    if col not in to_ignore:
        dataset5[col]=pd.qcut(dataset5[col],3,labels=['low', 'medium', 'high'])

# %%
dataset5
# Out:
#            District  \
# 0          Senapati
# 2        Tamenglong
# 4     Churachandpur
# 6         Bishnupur
# 7         Bishnupur
# ...             ...
# 1540       Longleng
# 1542        Kiphire
# 1544         Kohima
# 1545         Kohima
# 1547          Peren
#
#      1. Population (female) age 6+ years who ever attended school (%)  \
# 0                                                  high
# 2                                                medium
# 4                                                  high
# 6                                                  high
# 7                                                  high
# ...                                                 ...
# 1540                                               high
# 1542                                               high
# 1544                                               high
# 1545                                               high
# 1547                                               high
#
#      4. Sex ratio at birth for children born in the last five years (females per 1000 males)  \
# 0                                                   low
# 2                                                  high
# 4                                                  high
# 6                                                medium
# 7                                                medium
# ...                                                 ...
# 1540                                                low
# 1542                                             medium
# 1544                                               high
# 1545                                               high
# 1547                                             medium
#
#      7. Households with an improved drinking-water source1 (%)  \
# 0                                                   low
# 2                                                   low
# 4                                                   low
# 6                                                   low
# 7                                                   low
# ...                                                 ...
# 1540                                                low
# 1542                                             medium
# 1544                                                low
# 1545                                                low
# 1547                                                low
#
#      8. Households using improved sanitation facility2 (%)  \
# 0                                                  high
# 2                                                  high
# 4                                                  high
# 6                                                medium
# 7                                                medium
# ...                                                 ...
# 1540                                               high
# 1542                                               high
# 1544                                               high
# 1545                                               high
# 1547                                               high
#
#      9. Households using clean fuel for cooking3 (%)  \
# 0                                             medium
# 2                                                low
# 4                                               high
# 6                                               high
# 7                                             medium
# ...                                              ...
# 1540                                             low
# 1542                                             low
# 1544                                            high
# 1545                                          medium
# 1547                                             low
#
#      10. Households using iodized salt (%) 12. Women who are literate (%)  \
# 0                                     high                           high
# 2                                     high                         medium
# 4                                     high                           high
# 6                                     high                           high
# 7                                     high                           high
# ...                                    ...                            ...
# 1540                                  high                         medium
# 1542                                  high                         medium
# 1544                                  high                           high
# 1545                                  high                           high
# 1547                                  high                         medium
#
#      13. Men who are literate (%)  \
# 0                            high
# 2                            high
# 4                            high
# 6                            high
# 7                            high
# ...                           ...
# 1540                       medium
# 1542                          low
# 1544                         high
# 1545                       medium
# 1547                       medium
#
#      14. Women with 10 or more years of schooling (%)  ...  \
# 0                                              medium  ...
# 2                                              medium  ...
# 4                                                high  ...
# 6                                                high  ...
# 7                                              medium  ...
# ...                                               ...  ...
# 1540                                              low  ...
# 1542                                              low  ...
# 1544                                             high  ...
# 1545                                           medium  ...
# 1547                                              low  ...
#
#      72. Women whose Body Mass Index (BMI) is below normal (BMI <18.5 kg/m2) (%)  \
# 0                                                   low
# 2                                                   low
# 4                                                   low
# 6                                                   low
# 7                                                   low
# ...                                                 ...
# 1540                                                low
# 1542                                                low
# 1544                                                low
# 1545                                                low
# 1547                                                low
#
#      73. Men whose Body Mass Index (BMI) is below normal (BMI <18.5 kg/m2) (%)  \
# 0                                                   low
# 2                                                   low
# 4                                                   low
# 6                                                   low
# 7                                                   low
# ...                                                 ...
# 1540                                                low
# 1542                                                low
# 1544                                             medium
# 1545                                                low
# 1547                                                low
#
#      74. Women who are overweight or obese (BMI >=25.0 kg/m2) (%)  \
# 0                                                medium
# 2                                                medium
# 4                                                  high
# 6                                                  high
# 7                                                  high
# ...                                                 ...
# 1540                                                low
# 1542                                                low
# 1544                                               high
# 1545                                             medium
# 1547                                             medium
#
#      75. Men who are overweight or obese (BMI >=25.0 kg/m2) (%)  \
# 0                                                  high
# 2                                                   low
# 4                                                medium
# 6                                                  high
# 7                                                  high
# ...                                                 ...
# 1540                                                low
# 1542                                                low
# 1544                                               high
# 1545                                               high
# 1547                                                low
#
#      76. Children age 6-59 months who are anaemic (<11.0 g/dl) (%)  \
# 0                                                   low
# 2                                                   low
# 4                                                   low
# 6                                                   low
# 7                                                   low
# ...                                                 ...
# 1540                                                low
# 1542                                                low
# 1544                                                low
# 1545                                                low
# 1547                                                low
#
#      79. All women age 15-49 years who are anaemic (%)  \
# 0                                                  low
# 2                                                  low
# 4                                                  low
# 6                                                  low
# 7                                                  low
# ...                                                ...
# 1540                                               low
# 1542                                               low
# 1544                                               low
# 1545                                               low
# 1547                                               low
#
#      80. Men age 15-49 years who are anaemic (<13.0 g/dl) (%) State Region  \
# 0                                                   low          MN  Rural
# 2                                                   low          MN  Rural
# 4                                                   low          MN  Rural
# 6                                                   low          MN  Urban
# 7                                                   low          MN  Rural
# ...                                                 ...         ...    ...
# 1540                                                low          NL  Rural
# 1542                                                low          NL  Rural
# 1544                                                low          NL  Urban
# 1545                                                low          NL  Rural
# 1547                                                low          NL  Rural
#
#                     Zone
# 0     North Eastern Zone
# 2     North Eastern Zone
# 4     North Eastern Zone
# 6     North Eastern Zone
# 7     North Eastern Zone
# ...                  ...
# 1540  North Eastern Zone
# 1542  North Eastern Zone
# 1544  North Eastern Zone
# 1545  North Eastern Zone
# 1547  North Eastern Zone
#
# [654 rows x 32 columns]

# %%
dataset5.to_csv('./../Data/working_data/equal_frequency_discretised_data_6.csv')
